# %% [markdown]
# Can the reco loss be lowered by training just the decoder after pretraining with fixed encoder weights and pretraining the encoder on classification+reco? If we see an improvement is this just an effect of simply not enough epochs in the pretraining, i.e. can more training on classif+reco show the same effect of lowering the loss? Or is the decoder performance constrained by classifier performance and therefore cannot reach lower values? On the other hand can the decoder trained in isolation after pretraining reach the same loss value as training encoder+decoder in isolation? -> This would suggest that isolated training afterwards on given fixed latent space should yield optimal performance.

# %%
import sys; sys.path.insert(0, '..')
import utils
import keras
import numpy as np

def embed_and_translate(data, n_width, n_height):
    ndata = np.zeros((len(data), n_width, n_height, 1), dtype='float32')
    translations = np.empty((len(data), 2), dtype='float32')
    width, height = data.shape[1], data.shape[2]
    for i in range(len(data)):
        x = np.random.randint(n_width-width)
        y = np.random.randint(n_height-height)
        ndata[i][x:x+width, y:y+height] = data[i] # rows, cols = height, width
        translations[i][0] = x+(width//2)
        translations[i][1] = y+(height//2)
    return ndata, translations
            
n_splits = 16
output_shape = (56, 56, 1)
input_shape  = (14, 14, 1)
split_x, split_y = 14, 14
latent_dim = 4

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255.
x_train_augmented, y_train_regr = embed_and_translate(x_train, output_shape[0], output_shape[1])
x_train_split = np.array([utils.split(x, split_x, split_y) for x in x_train_augmented], dtype='float32')
y_train = keras.utils.to_categorical(y_train)

x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test = x_test.astype('float32') / 255.
x_test_augmented, y_test_regr = embed_and_translate(x_test, output_shape[0], output_shape[1])
x_test_split = np.array([utils.split(x, split_x, split_y) for x in x_test_augmented], dtype='float32')
y_test = keras.utils.to_categorical(y_test)

# %%
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation, Dropout, MaxPooling2D
from keras import Sequential
from keras.models import Model

import tensorflow as tf
import keras
import sys; sys.path.insert(0, '..')
import utils

class MultiSplit(Model):
    def __init__(self, n_splits, latent_dim, input_shape, output_shape):
        super(MultiSplit, self).__init__()
        self.encoder = self._create_encoder(latent_dim, input_shape)
        self.input_reshaper = utils.Reshaper((n_splits, *input_shape), input_shape)
        self.latent_reshaper = utils.Reshaper([latent_dim], [n_splits * latent_dim])
        self.decoder = self._create_decoder(n_splits * latent_dim, output_shape)
        self.classifier = self._create_classifier(n_splits * latent_dim)
        self.regressor = self._create_regressor(n_splits * latent_dim)
        
    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            y_pred = self(x)
            loss = self.compiled_loss(y, y_pred)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def test_step(self, data):
        x, y = data
        y_pred = self(x, training=False)
        self.compiled_loss(y, y_pred)
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, x, training=True):
        z = self.encode(x, training=training)
        y_reco = self.decode(z ,training=training)
        y_class = self.classify(z ,training=training)
        y_regr = self.regress(z ,training=training)
        return {"decoder_out": y_reco, "classifier_out": y_class, "regressor_out": y_regr}
        
    def encode(self, x, training=True):
        return self.encoder( self.input_reshaper(x) , training)
    
    def decode(self, z, training=True):
        return self.decoder( self.latent_reshaper(z) , training)
    
    def classify(self, z, training=True):
        return self.classifier( self.latent_reshaper(z) , training)
    
    def regress(self, z, training=True):
        return self.regressor( self.latent_reshaper(z) , training)
    
    def _create_encoder(self, latent_dim, input_shape, n_filters=[32,64]):
        return Sequential([
            Input(shape=input_shape),
            Conv2D(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2D(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Flatten(),
            Dense(units=latent_dim, activation='sigmoid')
        ], name='encoder')

    def _create_decoder(self, latent_dim, io_shape, n_filters=[32,64]):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(io_shape[0]//4 * io_shape[1]//4 * 8),  #! Reduce amount of neurons by 4.
            Reshape((io_shape[0]//4, io_shape[1]//4, 8)),
            Conv2DTranspose(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=1, kernel_size=(3,3), padding='same'),
            Activation('sigmoid', name='decoder_out')
        ])
    
    def _create_classifier(self, latent_dim):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(256, activation='relu'),
            Dense(128, activation='relu'),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax', name='classifier_out')
        ])
    
    def _create_regressor(self, latent_dim):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(256, activation='relu'),
            Dense(128, activation='relu'),
            Dense(64, activation='relu'),
            Dense(10, activation='relu'),
            Dense(2, activation='linear', name='regressor_out')
        ])

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy',
    'regressor_out' : 'mean_absolute_percentage_error'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.0,
    'regressor_out' : 0.0
}
model = MultiSplit(n_splits, latent_dim, input_shape, output_shape)

model.load_weights('../weights/43_CAE4x16_reco+class_epoch50_weights.h5') # MSE = 0.0062

for layer in model.encoder.layers:
    layer.trainable = False
for layer in model.regressor.layers:
    layer.trainable = False
    
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train_augmented, 'classifier_out': y_train, 'regressor_out': y_train_regr},
                    validation_data=(x_test_split, {'decoder_out': x_test_augmented, 'classifier_out': y_test, 'regressor_out':y_test_regr}),
                    epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0063 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0063 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9514 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 2/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0062 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0062 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 3/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0062 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0062 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 4/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0061 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 5/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0061 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 6/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0061 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 7/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0061 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 8/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0061 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 9/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 10/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 11/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9510 - val_regressor_out_accuracy: 0.5392
# Epoch 12/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 13/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 14/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 15/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 16/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 17/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 18/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0060 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 19/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 20/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 21/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 22/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 23/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 24/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9510 - val_regressor_out_accuracy: 0.5392
# Epoch 25/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 26/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 27/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0061 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 28/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9510 - val_regressor_out_accuracy: 0.5392
# Epoch 29/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 30/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 31/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 32/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 33/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 34/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 35/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 36/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 37/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 38/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 39/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 40/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0059 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9517 - val_regressor_out_accuracy: 0.5392
# Epoch 41/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 42/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 43/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 44/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 45/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 46/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0059 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0059 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 47/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 48/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0060 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 49/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0059 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0059 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 50/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0058 - classifier_out_loss: 0.4917 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8837 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0059 - val_classifier_out_loss: 0.4983 - val_decoder_out_loss: 0.0059 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8858 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392

# %% [markdown]
# Could the same decrease in val_decoder_out_loss also be achieved if we train classifier and decoder together for a few more epochs?

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy',
    'regressor_out' : 'mean_absolute_percentage_error'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.05,
    'regressor_out' : 0.0
}
model = MultiSplit(n_splits, latent_dim, input_shape, output_shape)

model.load_weights('../weights/43_CAE4x16_reco+class_epoch50_weights.h5') # MSE = 0.0062

for layer in model.encoder.layers:
    layer.trainable = False
for layer in model.regressor.layers:
    layer.trainable = False
    
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train_augmented, 'classifier_out': y_train, 'regressor_out': y_train_regr},
                    validation_data=(x_test_split, {'decoder_out': x_test_augmented, 'classifier_out': y_test, 'regressor_out':y_test_regr}),
                    epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0257 - classifier_out_loss: 0.3887 - decoder_out_loss: 0.0063 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8829 - decoder_out_accuracy: 0.9514 - regressor_out_accuracy: 0.5416 - val_loss: 0.0248 - val_classifier_out_loss: 0.3733 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8851 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 2/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0223 - classifier_out_loss: 0.3226 - decoder_out_loss: 0.0062 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.8954 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0241 - val_classifier_out_loss: 0.3605 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8902 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 3/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0208 - classifier_out_loss: 0.2938 - decoder_out_loss: 0.0062 - regressor_out_loss: 99.8674 - classifier_out_accuracy: 0.9040 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0228 - val_classifier_out_loss: 0.3335 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8983 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 4/50
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0198 - classifier_out_loss: 0.2730 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9093 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0231 - val_classifier_out_loss: 0.3386 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8985 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 5/50
# 1875/1875 [==============================] - 21s 11ms/step - loss: 0.0188 - classifier_out_loss: 0.2539 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9151 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0231 - val_classifier_out_loss: 0.3393 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8960 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 6/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0182 - classifier_out_loss: 0.2419 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9174 - decoder_out_accuracy: 0.9515 - regressor_out_accuracy: 0.5416 - val_loss: 0.0243 - val_classifier_out_loss: 0.3636 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8897 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 7/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0175 - classifier_out_loss: 0.2279 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9221 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0236 - val_classifier_out_loss: 0.3496 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8932 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 8/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0170 - classifier_out_loss: 0.2182 - decoder_out_loss: 0.0061 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9253 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0244 - val_classifier_out_loss: 0.3675 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8908 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 9/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0164 - classifier_out_loss: 0.2079 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9289 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0239 - val_classifier_out_loss: 0.3568 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8936 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 10/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0159 - classifier_out_loss: 0.1967 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9317 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0236 - val_classifier_out_loss: 0.3487 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8977 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 11/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0156 - classifier_out_loss: 0.1916 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9340 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0235 - val_classifier_out_loss: 0.3467 - val_decoder_out_loss: 0.0062 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8987 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 12/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0151 - classifier_out_loss: 0.1819 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9374 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0242 - val_classifier_out_loss: 0.3626 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8985 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 13/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0147 - classifier_out_loss: 0.1730 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9402 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0238 - val_classifier_out_loss: 0.3536 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8979 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 14/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0145 - classifier_out_loss: 0.1695 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9402 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0243 - val_classifier_out_loss: 0.3644 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8999 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 15/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0140 - classifier_out_loss: 0.1611 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9433 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0246 - val_classifier_out_loss: 0.3695 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8974 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 16/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0138 - classifier_out_loss: 0.1556 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9466 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0257 - val_classifier_out_loss: 0.3926 - val_decoder_out_loss: 0.0061 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8920 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 17/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0135 - classifier_out_loss: 0.1498 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9473 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0250 - val_classifier_out_loss: 0.3783 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.9017 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 18/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0133 - classifier_out_loss: 0.1463 - decoder_out_loss: 0.0060 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9485 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0255 - val_classifier_out_loss: 0.3896 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8944 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 19/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0130 - classifier_out_loss: 0.1401 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9508 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0257 - val_classifier_out_loss: 0.3936 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8953 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 20/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0129 - classifier_out_loss: 0.1381 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9510 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0258 - val_classifier_out_loss: 0.3958 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8983 - val_decoder_out_accuracy: 0.9511 - val_regressor_out_accuracy: 0.5392
# Epoch 21/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0126 - classifier_out_loss: 0.1327 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9532 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0263 - val_classifier_out_loss: 0.4061 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8970 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 22/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0123 - classifier_out_loss: 0.1265 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9553 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0265 - val_classifier_out_loss: 0.4092 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8989 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 23/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0121 - classifier_out_loss: 0.1233 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9564 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0269 - val_classifier_out_loss: 0.4166 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8962 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 24/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0119 - classifier_out_loss: 0.1205 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9578 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0276 - val_classifier_out_loss: 0.4315 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8938 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 25/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0118 - classifier_out_loss: 0.1187 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9578 - decoder_out_accuracy: 0.9516 - regressor_out_accuracy: 0.5416 - val_loss: 0.0269 - val_classifier_out_loss: 0.4175 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8965 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 26/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0116 - classifier_out_loss: 0.1145 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9584 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0283 - val_classifier_out_loss: 0.4453 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8941 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 27/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0114 - classifier_out_loss: 0.1105 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9600 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0284 - val_classifier_out_loss: 0.4477 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8932 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 28/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0113 - classifier_out_loss: 0.1087 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9608 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0279 - val_classifier_out_loss: 0.4378 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8943 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 29/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0110 - classifier_out_loss: 0.1027 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9632 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0283 - val_classifier_out_loss: 0.4457 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8975 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 30/50
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0109 - classifier_out_loss: 0.1011 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9638 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0295 - val_classifier_out_loss: 0.4698 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8879 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 31/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0108 - classifier_out_loss: 0.0988 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9642 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0293 - val_classifier_out_loss: 0.4653 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8949 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 32/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0107 - classifier_out_loss: 0.0954 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9657 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0299 - val_classifier_out_loss: 0.4772 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8924 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 33/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0106 - classifier_out_loss: 0.0949 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9650 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0296 - val_classifier_out_loss: 0.4716 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8932 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 34/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0105 - classifier_out_loss: 0.0926 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9668 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0312 - val_classifier_out_loss: 0.5038 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8896 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 35/50
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0104 - classifier_out_loss: 0.0897 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9683 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0300 - val_classifier_out_loss: 0.4787 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8930 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 36/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0102 - classifier_out_loss: 0.0874 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9680 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0310 - val_classifier_out_loss: 0.4992 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8953 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 37/50
# 1875/1875 [==============================] - 23s 13ms/step - loss: 0.0104 - classifier_out_loss: 0.0899 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9682 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0315 - val_classifier_out_loss: 0.5107 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8932 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 38/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0100 - classifier_out_loss: 0.0820 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9706 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0315 - val_classifier_out_loss: 0.5108 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8970 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 39/50
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0101 - classifier_out_loss: 0.0845 - decoder_out_loss: 0.0059 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9699 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0326 - val_classifier_out_loss: 0.5318 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8869 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 40/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0100 - classifier_out_loss: 0.0822 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9699 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0322 - val_classifier_out_loss: 0.5243 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8939 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 41/50
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0099 - classifier_out_loss: 0.0810 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9712 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0335 - val_classifier_out_loss: 0.5500 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8885 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 42/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0097 - classifier_out_loss: 0.0780 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9714 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0320 - val_classifier_out_loss: 0.5213 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8928 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 43/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0097 - classifier_out_loss: 0.0778 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9715 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0339 - val_classifier_out_loss: 0.5579 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8897 - val_decoder_out_accuracy: 0.9515 - val_regressor_out_accuracy: 0.5392
# Epoch 44/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0096 - classifier_out_loss: 0.0749 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8673 - classifier_out_accuracy: 0.9732 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0328 - val_classifier_out_loss: 0.5372 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8963 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 45/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0096 - classifier_out_loss: 0.0760 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9728 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0324 - val_classifier_out_loss: 0.5296 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8965 - val_decoder_out_accuracy: 0.9512 - val_regressor_out_accuracy: 0.5392
# Epoch 46/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0095 - classifier_out_loss: 0.0739 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9732 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0349 - val_classifier_out_loss: 0.5786 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8867 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 47/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0095 - classifier_out_loss: 0.0742 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9726 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0340 - val_classifier_out_loss: 0.5613 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8959 - val_decoder_out_accuracy: 0.9513 - val_regressor_out_accuracy: 0.5392
# Epoch 48/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0094 - classifier_out_loss: 0.0712 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9742 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0357 - val_classifier_out_loss: 0.5949 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8855 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
# Epoch 49/50
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0095 - classifier_out_loss: 0.0737 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8671 - classifier_out_accuracy: 0.9735 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0332 - val_classifier_out_loss: 0.5455 - val_decoder_out_loss: 0.0060 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8960 - val_decoder_out_accuracy: 0.9516 - val_regressor_out_accuracy: 0.5392
# Epoch 50/50
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0092 - classifier_out_loss: 0.0668 - decoder_out_loss: 0.0058 - regressor_out_loss: 99.8672 - classifier_out_accuracy: 0.9755 - decoder_out_accuracy: 0.9517 - regressor_out_accuracy: 0.5416 - val_loss: 0.0347 - val_classifier_out_loss: 0.5757 - val_decoder_out_loss: 0.0059 - val_regressor_out_loss: 99.8661 - val_classifier_out_accuracy: 0.8936 - val_decoder_out_accuracy: 0.9514 - val_regressor_out_accuracy: 0.5392
