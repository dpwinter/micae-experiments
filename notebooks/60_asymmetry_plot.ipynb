# %%
import matplotlib.pyplot as plt

x = [(w_r - w_c)/(w_r + w_c) for w_r, w_c in [(1,0), (1,1), (0,1)]]

y_r = [1.2721, 1.5217, 2.9215]
y_c = [0.8090, 0.3986, 0.3248]

y_r0 = 1.5217
y_c0 = 0.3986

y_r_rel = [y/y_r0 for y in y_r]
y_c_rel = [y/y_c0 for y in y_c]

# fig, ax1 = plt.subplots()

# ax1.set_ylabel('MAPE validation loss')
# ax1.plot(x, y_r, 'o-')
# ax1.set_xlabel('$(LW_{reg}-LW_{class})/(LW_{reg}+LW_{class})$')
# ax1.set_xticks([-1,0,1])
# ax2 = ax1.twinx()

# ax2.set_ylabel('CCE validation loss')
# ax2.plot(x, y_c, 'o-', color='tab:red')

plt.plot(x, y_r_rel, 'o-')
plt.plot(x, y_c_rel, 'o-')
plt.xlabel('$(LW_{reg}-LW_{class})/(LW_{reg}+LW_{class})$')
plt.xticks([-1,0,1])
plt.ylabel('$L/L_{0}$')
plt.legend(['MAPE', 'CCE'])


plt.savefig('../img/60/asym.png', dpi=200)
