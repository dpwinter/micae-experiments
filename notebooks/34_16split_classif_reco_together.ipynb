# %% [markdown]
# Compare the results of E33 with training classifier and decoder (reco) together. In the latter case accuracy looks much better (~91%, the assumed max from E32).

# %%
import sys; sys.path.insert(0, '..')
import utils
import keras
import numpy as np

def embed_and_translate(data, nrows, ncols):
    ndata = np.zeros((len(data), nrows, ncols, 1), dtype='float32')
    translations = np.empty((len(data), 2), dtype='float32')
    width, height = data.shape[1], data.shape[2]
    for i in range(len(data)):
        x = np.random.randint(ncols-width)
        y = np.random.randint(nrows-height)
        ndata[i][x:x+width, y:y+height] = data[i] # rows, cols = height, width
        translations[i][0] = x+(width//2)
        translations[i][1] = y+(height//2)
    return ndata, translations
            
n_splits = 16
io_shape = (56,56,1)
size = int(io_shape[0] // (n_splits**(1/2)))
latent_dim = 16 * 4 # since we have 4x4-splits we need 4 times the latent space for a fair comparison.

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255.
x_train_augmented, y_train_reco = embed_and_translate(x_train, 56, 56)
x_train_split = np.array([utils.split(x, size, size) for x in x_train_augmented], dtype='float32')
y_train = keras.utils.to_categorical(y_train)

x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test = x_test.astype('float32') / 255.
x_test_augmented, y_test_reco = embed_and_translate(x_test, 56, 56)
x_test_split = np.array([utils.split(x, size, size) for x in x_test_augmented], dtype='float32')
y_test = keras.utils.to_categorical(y_test)

# %%
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation, Dropout
from keras import Sequential
from keras.models import Model

import tensorflow as tf
import keras
import sys; sys.path.insert(0, '..')
import utils

class MultiSplit(Model):
    def __init__(self, n_splits, latent_dim, io_shape):
        super(MultiSplit, self).__init__()
        n_filters = [32, 64]
        size = int( io_shape[0] // (n_splits**(1/2)) )  # W = H
        self.encoder = self._create_encoder(latent_dim//n_splits, (size, size,1), n_filters)
        self.input_reshaper = utils.Reshaper((n_splits, size, size, 1), (size, size,1))
        self.latent_reshaper = utils.Reshaper([latent_dim//n_splits], [latent_dim])
        self.classifier = self._create_classifier(latent_dim)
        self.decoder = self._create_decoder(latent_dim, io_shape, n_filters)
        
    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            y_pred = self(x)
            loss = self.compiled_loss(y, y_pred)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def test_step(self, data):
        x, y = data
        y_pred = self(x, training=False)
        self.compiled_loss(y, y_pred)
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, x, training=True):
        z = self.encode(x, training=training)
        y_reco = self.decode(z ,training=training)
        y_class = self.classify(z ,training=training)
        return {"decoder_out": y_reco, "classifier_out": y_class}
        
    def encode(self, x, training=True):
        return self.encoder( self.input_reshaper(x) , training)
    
    def decode(self, z, training=True):
        return self.decoder( self.latent_reshaper(z) , training)
    
    def classify(self, z, training=True):
        return self.classifier( self.latent_reshaper(z) , training)
    
    def _create_encoder(self, latent_dim, input_shape, n_filters):
        return Sequential([
            Input(shape=input_shape),
            Conv2D(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2D(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Flatten(),
            Dense(units=latent_dim, activation='sigmoid')
        ], name='encoder')

    def _create_decoder(self, latent_dim, io_shape, n_filters):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(io_shape[0]//4 * io_shape[1]//4 * 8),
            Reshape((io_shape[0]//4, io_shape[1]//4, 8)),
            Conv2DTranspose(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=1, kernel_size=(3,3), padding='same'),
            Activation('sigmoid', name='decoder_out')
        ])
    
    def _create_classifier(self, latent_dim):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(64, activation='relu'),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax')
        ])

# %% [markdown]
# 1. Givin classification loss of 0.005 (as was done for the 4-split in E27) seems to be too low in the case of 16-split.

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.005
}
model = MultiSplit(n_splits, latent_dim, io_shape)
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train_augmented, 'classifier_out': y_train},
                    validation_data=(x_test_split, {'decoder_out': x_test_augmented, 'classifier_out': y_test}),
                    epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0276 - classifier_out_loss: 1.9960 - decoder_out_loss: 0.0176 - classifier_out_accuracy: 0.2537 - decoder_out_accuracy: 0.9496 - val_loss: 0.0197 - val_classifier_out_loss: 1.6300 - val_decoder_out_loss: 0.0116 - val_classifier_out_accuracy: 0.4028 - val_decoder_out_accuracy: 0.9463
# Epoch 2/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0181 - classifier_out_loss: 1.4465 - decoder_out_loss: 0.0108 - classifier_out_accuracy: 0.4804 - decoder_out_accuracy: 0.9470 - val_loss: 0.0165 - val_classifier_out_loss: 1.2838 - val_decoder_out_loss: 0.0101 - val_classifier_out_accuracy: 0.5416 - val_decoder_out_accuracy: 0.9475
# Epoch 3/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0157 - classifier_out_loss: 1.1690 - decoder_out_loss: 0.0098 - classifier_out_accuracy: 0.5860 - decoder_out_accuracy: 0.9482 - val_loss: 0.0148 - val_classifier_out_loss: 1.0499 - val_decoder_out_loss: 0.0096 - val_classifier_out_accuracy: 0.6290 - val_decoder_out_accuracy: 0.9483
# Epoch 4/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0142 - classifier_out_loss: 0.9612 - decoder_out_loss: 0.0094 - classifier_out_accuracy: 0.6641 - decoder_out_accuracy: 0.9490 - val_loss: 0.0136 - val_classifier_out_loss: 0.8671 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.6996 - val_decoder_out_accuracy: 0.9489
# Epoch 5/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0132 - classifier_out_loss: 0.8092 - decoder_out_loss: 0.0091 - classifier_out_accuracy: 0.7217 - decoder_out_accuracy: 0.9495 - val_loss: 0.0128 - val_classifier_out_loss: 0.7578 - val_decoder_out_loss: 0.0090 - val_classifier_out_accuracy: 0.7411 - val_decoder_out_accuracy: 0.9494
# Epoch 6/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0124 - classifier_out_loss: 0.7051 - decoder_out_loss: 0.0089 - classifier_out_accuracy: 0.7597 - decoder_out_accuracy: 0.9498 - val_loss: 0.0122 - val_classifier_out_loss: 0.6896 - val_decoder_out_loss: 0.0088 - val_classifier_out_accuracy: 0.7660 - val_decoder_out_accuracy: 0.9495
# Epoch 7/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0119 - classifier_out_loss: 0.6350 - decoder_out_loss: 0.0087 - classifier_out_accuracy: 0.7855 - decoder_out_accuracy: 0.9500 - val_loss: 0.0118 - val_classifier_out_loss: 0.6313 - val_decoder_out_loss: 0.0086 - val_classifier_out_accuracy: 0.7896 - val_decoder_out_accuracy: 0.9501
# Epoch 8/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0114 - classifier_out_loss: 0.5816 - decoder_out_loss: 0.0085 - classifier_out_accuracy: 0.8038 - decoder_out_accuracy: 0.9502 - val_loss: 0.0113 - val_classifier_out_loss: 0.5773 - val_decoder_out_loss: 0.0084 - val_classifier_out_accuracy: 0.8118 - val_decoder_out_accuracy: 0.9502
# Epoch 9/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0111 - classifier_out_loss: 0.5454 - decoder_out_loss: 0.0083 - classifier_out_accuracy: 0.8173 - decoder_out_accuracy: 0.9503 - val_loss: 0.0112 - val_classifier_out_loss: 0.5872 - val_decoder_out_loss: 0.0083 - val_classifier_out_accuracy: 0.8084 - val_decoder_out_accuracy: 0.9502
# Epoch 10/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0107 - classifier_out_loss: 0.5092 - decoder_out_loss: 0.0082 - classifier_out_accuracy: 0.8306 - decoder_out_accuracy: 0.9504 - val_loss: 0.0108 - val_classifier_out_loss: 0.5341 - val_decoder_out_loss: 0.0081 - val_classifier_out_accuracy: 0.8245 - val_decoder_out_accuracy: 0.9502
# Epoch 11/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0105 - classifier_out_loss: 0.4825 - decoder_out_loss: 0.0081 - classifier_out_accuracy: 0.8415 - decoder_out_accuracy: 0.9504 - val_loss: 0.0107 - val_classifier_out_loss: 0.5303 - val_decoder_out_loss: 0.0081 - val_classifier_out_accuracy: 0.8296 - val_decoder_out_accuracy: 0.9500
# Epoch 12/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0103 - classifier_out_loss: 0.4622 - decoder_out_loss: 0.0080 - classifier_out_accuracy: 0.8478 - decoder_out_accuracy: 0.9505 - val_loss: 0.0105 - val_classifier_out_loss: 0.4994 - val_decoder_out_loss: 0.0080 - val_classifier_out_accuracy: 0.8322 - val_decoder_out_accuracy: 0.9501
# Epoch 13/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0101 - classifier_out_loss: 0.4402 - decoder_out_loss: 0.0079 - classifier_out_accuracy: 0.8540 - decoder_out_accuracy: 0.9506 - val_loss: 0.0103 - val_classifier_out_loss: 0.4791 - val_decoder_out_loss: 0.0079 - val_classifier_out_accuracy: 0.8471 - val_decoder_out_accuracy: 0.9504
# Epoch 14/25
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0099 - classifier_out_loss: 0.4234 - decoder_out_loss: 0.0078 - classifier_out_accuracy: 0.8631 - decoder_out_accuracy: 0.9506 - val_loss: 0.0102 - val_classifier_out_loss: 0.4773 - val_decoder_out_loss: 0.0078 - val_classifier_out_accuracy: 0.8454 - val_decoder_out_accuracy: 0.9505
# Epoch 15/25
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0097 - classifier_out_loss: 0.4061 - decoder_out_loss: 0.0077 - classifier_out_accuracy: 0.8668 - decoder_out_accuracy: 0.9507 - val_loss: 0.0102 - val_classifier_out_loss: 0.4870 - val_decoder_out_loss: 0.0078 - val_classifier_out_accuracy: 0.8460 - val_decoder_out_accuracy: 0.9502
# Epoch 16/25
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0096 - classifier_out_loss: 0.3923 - decoder_out_loss: 0.0076 - classifier_out_accuracy: 0.8708 - decoder_out_accuracy: 0.9507 - val_loss: 0.0100 - val_classifier_out_loss: 0.4464 - val_decoder_out_loss: 0.0077 - val_classifier_out_accuracy: 0.8589 - val_decoder_out_accuracy: 0.9505
# Epoch 17/25
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0094 - classifier_out_loss: 0.3785 - decoder_out_loss: 0.0076 - classifier_out_accuracy: 0.8766 - decoder_out_accuracy: 0.9507 - val_loss: 0.0099 - val_classifier_out_loss: 0.4406 - val_decoder_out_loss: 0.0077 - val_classifier_out_accuracy: 0.8564 - val_decoder_out_accuracy: 0.9499
# Epoch 18/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0093 - classifier_out_loss: 0.3681 - decoder_out_loss: 0.0075 - classifier_out_accuracy: 0.8792 - decoder_out_accuracy: 0.9508 - val_loss: 0.0098 - val_classifier_out_loss: 0.4459 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.8545 - val_decoder_out_accuracy: 0.9507
# Epoch 19/25
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0092 - classifier_out_loss: 0.3561 - decoder_out_loss: 0.0075 - classifier_out_accuracy: 0.8833 - decoder_out_accuracy: 0.9508 - val_loss: 0.0097 - val_classifier_out_loss: 0.4325 - val_decoder_out_loss: 0.0076 - val_classifier_out_accuracy: 0.8613 - val_decoder_out_accuracy: 0.9505
# Epoch 20/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0091 - classifier_out_loss: 0.3455 - decoder_out_loss: 0.0074 - classifier_out_accuracy: 0.8876 - decoder_out_accuracy: 0.9508 - val_loss: 0.0096 - val_classifier_out_loss: 0.4236 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.8623 - val_decoder_out_accuracy: 0.9505
# Epoch 21/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0091 - classifier_out_loss: 0.3368 - decoder_out_loss: 0.0074 - classifier_out_accuracy: 0.8887 - decoder_out_accuracy: 0.9508 - val_loss: 0.0097 - val_classifier_out_loss: 0.4536 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.8544 - val_decoder_out_accuracy: 0.9503
# Epoch 22/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0090 - classifier_out_loss: 0.3279 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.8918 - decoder_out_accuracy: 0.9509 - val_loss: 0.0096 - val_classifier_out_loss: 0.4324 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.8632 - val_decoder_out_accuracy: 0.9506
# Epoch 23/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0089 - classifier_out_loss: 0.3227 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.8943 - decoder_out_accuracy: 0.9509 - val_loss: 0.0096 - val_classifier_out_loss: 0.4409 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.8604 - val_decoder_out_accuracy: 0.9508
# Epoch 24/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0088 - classifier_out_loss: 0.3144 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.8964 - decoder_out_accuracy: 0.9509 - val_loss: 0.0094 - val_classifier_out_loss: 0.4112 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.8683 - val_decoder_out_accuracy: 0.9510
# Epoch 25/25
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0087 - classifier_out_loss: 0.3072 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.8993 - decoder_out_accuracy: 0.9509 - val_loss: 0.0093 - val_classifier_out_loss: 0.4042 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.8707 - val_decoder_out_accuracy: 0.9506

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axes[0].set_title('Reconstruction Loss')
axes[0].plot(history.history['decoder_out_loss'])
axes[0].plot(history.history['val_decoder_out_loss'])
axes[0].set_ylabel('MSE loss')
axes[0].set_xlabel('epoch')
axes[0].legend(['train', 'test'], loc='upper right')

axes[1].set_title('Classification Accuracy')
axes[1].plot(history.history['classifier_out_accuracy'])
axes[1].plot(history.history['val_classifier_out_accuracy'])
axes[1].set_ylabel('accuracy')
axes[1].set_xlabel('epoch')
axes[1].legend(['train', 'test'], loc='lower right')

fig.tight_layout()
# fig.show()
fig.savefig('../img/34/CE4x16_reco1_classify0.005.png')

# %% [markdown]
# 2. Giving the classification loss double the impact on training seems to be a good choice.

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.01
}
model = MultiSplit(n_splits, latent_dim, io_shape)
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train_augmented, 'classifier_out': y_train},
                    validation_data=(x_test_split, {'decoder_out': x_test_augmented, 'classifier_out': y_test}),
                    epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0348 - classifier_out_loss: 1.8704 - decoder_out_loss: 0.0161 - classifier_out_accuracy: 0.3050 - decoder_out_accuracy: 0.9490 - val_loss: 0.0260 - val_classifier_out_loss: 1.3935 - val_decoder_out_loss: 0.0121 - val_classifier_out_accuracy: 0.4803 - val_decoder_out_accuracy: 0.9466
# Epoch 2/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0230 - classifier_out_loss: 1.1136 - decoder_out_loss: 0.0119 - classifier_out_accuracy: 0.6073 - decoder_out_accuracy: 0.9466 - val_loss: 0.0200 - val_classifier_out_loss: 0.8619 - val_decoder_out_loss: 0.0114 - val_classifier_out_accuracy: 0.7077 - val_decoder_out_accuracy: 0.9468
# Epoch 3/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0188 - classifier_out_loss: 0.7840 - decoder_out_loss: 0.0110 - classifier_out_accuracy: 0.7356 - decoder_out_accuracy: 0.9478 - val_loss: 0.0171 - val_classifier_out_loss: 0.6461 - val_decoder_out_loss: 0.0106 - val_classifier_out_accuracy: 0.7856 - val_decoder_out_accuracy: 0.9481
# Epoch 4/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0166 - classifier_out_loss: 0.6130 - decoder_out_loss: 0.0104 - classifier_out_accuracy: 0.7961 - decoder_out_accuracy: 0.9487 - val_loss: 0.0157 - val_classifier_out_loss: 0.5513 - val_decoder_out_loss: 0.0102 - val_classifier_out_accuracy: 0.8167 - val_decoder_out_accuracy: 0.9485
# Epoch 5/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0152 - classifier_out_loss: 0.5151 - decoder_out_loss: 0.0100 - classifier_out_accuracy: 0.8288 - decoder_out_accuracy: 0.9492 - val_loss: 0.0146 - val_classifier_out_loss: 0.4717 - val_decoder_out_loss: 0.0099 - val_classifier_out_accuracy: 0.8484 - val_decoder_out_accuracy: 0.9492
# Epoch 6/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0142 - classifier_out_loss: 0.4523 - decoder_out_loss: 0.0097 - classifier_out_accuracy: 0.8525 - decoder_out_accuracy: 0.9495 - val_loss: 0.0138 - val_classifier_out_loss: 0.4261 - val_decoder_out_loss: 0.0095 - val_classifier_out_accuracy: 0.8614 - val_decoder_out_accuracy: 0.9492
# Epoch 7/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0135 - classifier_out_loss: 0.4111 - decoder_out_loss: 0.0094 - classifier_out_accuracy: 0.8645 - decoder_out_accuracy: 0.9498 - val_loss: 0.0133 - val_classifier_out_loss: 0.3936 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.8747 - val_decoder_out_accuracy: 0.9498
# Epoch 8/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0130 - classifier_out_loss: 0.3818 - decoder_out_loss: 0.0092 - classifier_out_accuracy: 0.8754 - decoder_out_accuracy: 0.9499 - val_loss: 0.0131 - val_classifier_out_loss: 0.4005 - val_decoder_out_loss: 0.0091 - val_classifier_out_accuracy: 0.8718 - val_decoder_out_accuracy: 0.9498
# Epoch 9/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0126 - classifier_out_loss: 0.3601 - decoder_out_loss: 0.0090 - classifier_out_accuracy: 0.8814 - decoder_out_accuracy: 0.9500 - val_loss: 0.0130 - val_classifier_out_loss: 0.4056 - val_decoder_out_loss: 0.0090 - val_classifier_out_accuracy: 0.8665 - val_decoder_out_accuracy: 0.9494
# Epoch 10/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0122 - classifier_out_loss: 0.3412 - decoder_out_loss: 0.0088 - classifier_out_accuracy: 0.8881 - decoder_out_accuracy: 0.9501 - val_loss: 0.0124 - val_classifier_out_loss: 0.3553 - val_decoder_out_loss: 0.0088 - val_classifier_out_accuracy: 0.8880 - val_decoder_out_accuracy: 0.9494
# Epoch 11/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0119 - classifier_out_loss: 0.3202 - decoder_out_loss: 0.0087 - classifier_out_accuracy: 0.8959 - decoder_out_accuracy: 0.9502 - val_loss: 0.0122 - val_classifier_out_loss: 0.3440 - val_decoder_out_loss: 0.0088 - val_classifier_out_accuracy: 0.8922 - val_decoder_out_accuracy: 0.9507
# Epoch 12/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0116 - classifier_out_loss: 0.3074 - decoder_out_loss: 0.0086 - classifier_out_accuracy: 0.9002 - decoder_out_accuracy: 0.9503 - val_loss: 0.0118 - val_classifier_out_loss: 0.3286 - val_decoder_out_loss: 0.0085 - val_classifier_out_accuracy: 0.8923 - val_decoder_out_accuracy: 0.9497
# Epoch 13/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0114 - classifier_out_loss: 0.2938 - decoder_out_loss: 0.0084 - classifier_out_accuracy: 0.9042 - decoder_out_accuracy: 0.9503 - val_loss: 0.0120 - val_classifier_out_loss: 0.3473 - val_decoder_out_loss: 0.0085 - val_classifier_out_accuracy: 0.8872 - val_decoder_out_accuracy: 0.9500
# Epoch 14/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0112 - classifier_out_loss: 0.2843 - decoder_out_loss: 0.0083 - classifier_out_accuracy: 0.9068 - decoder_out_accuracy: 0.9504 - val_loss: 0.0117 - val_classifier_out_loss: 0.3313 - val_decoder_out_loss: 0.0084 - val_classifier_out_accuracy: 0.8960 - val_decoder_out_accuracy: 0.9496
# Epoch 15/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0110 - classifier_out_loss: 0.2721 - decoder_out_loss: 0.0082 - classifier_out_accuracy: 0.9103 - decoder_out_accuracy: 0.9504 - val_loss: 0.0115 - val_classifier_out_loss: 0.3205 - val_decoder_out_loss: 0.0083 - val_classifier_out_accuracy: 0.9020 - val_decoder_out_accuracy: 0.9505
# Epoch 16/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0108 - classifier_out_loss: 0.2629 - decoder_out_loss: 0.0081 - classifier_out_accuracy: 0.9141 - decoder_out_accuracy: 0.9505 - val_loss: 0.0113 - val_classifier_out_loss: 0.3141 - val_decoder_out_loss: 0.0081 - val_classifier_out_accuracy: 0.9010 - val_decoder_out_accuracy: 0.9502
# Epoch 17/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0106 - classifier_out_loss: 0.2569 - decoder_out_loss: 0.0081 - classifier_out_accuracy: 0.9164 - decoder_out_accuracy: 0.9505 - val_loss: 0.0114 - val_classifier_out_loss: 0.3181 - val_decoder_out_loss: 0.0082 - val_classifier_out_accuracy: 0.9026 - val_decoder_out_accuracy: 0.9506
# Epoch 18/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0104 - classifier_out_loss: 0.2449 - decoder_out_loss: 0.0080 - classifier_out_accuracy: 0.9194 - decoder_out_accuracy: 0.9506 - val_loss: 0.0110 - val_classifier_out_loss: 0.2997 - val_decoder_out_loss: 0.0080 - val_classifier_out_accuracy: 0.9079 - val_decoder_out_accuracy: 0.9505
# Epoch 19/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0103 - classifier_out_loss: 0.2375 - decoder_out_loss: 0.0079 - classifier_out_accuracy: 0.9220 - decoder_out_accuracy: 0.9506 - val_loss: 0.0113 - val_classifier_out_loss: 0.3327 - val_decoder_out_loss: 0.0080 - val_classifier_out_accuracy: 0.8952 - val_decoder_out_accuracy: 0.9502
# Epoch 20/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0101 - classifier_out_loss: 0.2329 - decoder_out_loss: 0.0078 - classifier_out_accuracy: 0.9237 - decoder_out_accuracy: 0.9506 - val_loss: 0.0110 - val_classifier_out_loss: 0.3084 - val_decoder_out_loss: 0.0079 - val_classifier_out_accuracy: 0.9074 - val_decoder_out_accuracy: 0.9506
# Epoch 21/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0100 - classifier_out_loss: 0.2264 - decoder_out_loss: 0.0078 - classifier_out_accuracy: 0.9254 - decoder_out_accuracy: 0.9507 - val_loss: 0.0114 - val_classifier_out_loss: 0.3466 - val_decoder_out_loss: 0.0079 - val_classifier_out_accuracy: 0.8922 - val_decoder_out_accuracy: 0.9502
# Epoch 22/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0099 - classifier_out_loss: 0.2212 - decoder_out_loss: 0.0077 - classifier_out_accuracy: 0.9270 - decoder_out_accuracy: 0.9507 - val_loss: 0.0108 - val_classifier_out_loss: 0.3050 - val_decoder_out_loss: 0.0078 - val_classifier_out_accuracy: 0.9090 - val_decoder_out_accuracy: 0.9504
# Epoch 23/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0098 - classifier_out_loss: 0.2126 - decoder_out_loss: 0.0077 - classifier_out_accuracy: 0.9298 - decoder_out_accuracy: 0.9507 - val_loss: 0.0108 - val_classifier_out_loss: 0.3040 - val_decoder_out_loss: 0.0077 - val_classifier_out_accuracy: 0.9061 - val_decoder_out_accuracy: 0.9502
# Epoch 24/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0097 - classifier_out_loss: 0.2066 - decoder_out_loss: 0.0076 - classifier_out_accuracy: 0.9310 - decoder_out_accuracy: 0.9508 - val_loss: 0.0110 - val_classifier_out_loss: 0.3213 - val_decoder_out_loss: 0.0078 - val_classifier_out_accuracy: 0.8992 - val_decoder_out_accuracy: 0.9508
# Epoch 25/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0096 - classifier_out_loss: 0.2042 - decoder_out_loss: 0.0076 - classifier_out_accuracy: 0.9334 - decoder_out_accuracy: 0.9508 - val_loss: 0.0112 - val_classifier_out_loss: 0.3452 - val_decoder_out_loss: 0.0077 - val_classifier_out_accuracy: 0.8950 - val_decoder_out_accuracy: 0.9508
# Epoch 26/100
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.0095 - classifier_out_loss: 0.1967 - decoder_out_loss: 0.0075 - classifier_out_accuracy: 0.9352 - decoder_out_accuracy: 0.9508 - val_loss: 0.0107 - val_classifier_out_loss: 0.3012 - val_decoder_out_loss: 0.0077 - val_classifier_out_accuracy: 0.9082 - val_decoder_out_accuracy: 0.9502
# Epoch 27/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0095 - classifier_out_loss: 0.1969 - decoder_out_loss: 0.0075 - classifier_out_accuracy: 0.9357 - decoder_out_accuracy: 0.9508 - val_loss: 0.0104 - val_classifier_out_loss: 0.2839 - val_decoder_out_loss: 0.0076 - val_classifier_out_accuracy: 0.9158 - val_decoder_out_accuracy: 0.9506
# Epoch 28/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0093 - classifier_out_loss: 0.1891 - decoder_out_loss: 0.0074 - classifier_out_accuracy: 0.9378 - decoder_out_accuracy: 0.9508 - val_loss: 0.0106 - val_classifier_out_loss: 0.3032 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.9077 - val_decoder_out_accuracy: 0.9506
# Epoch 29/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0093 - classifier_out_loss: 0.1878 - decoder_out_loss: 0.0074 - classifier_out_accuracy: 0.9380 - decoder_out_accuracy: 0.9509 - val_loss: 0.0105 - val_classifier_out_loss: 0.2927 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.9114 - val_decoder_out_accuracy: 0.9502
# Epoch 30/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0092 - classifier_out_loss: 0.1830 - decoder_out_loss: 0.0074 - classifier_out_accuracy: 0.9393 - decoder_out_accuracy: 0.9509 - val_loss: 0.0106 - val_classifier_out_loss: 0.3106 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.9065 - val_decoder_out_accuracy: 0.9509
# Epoch 31/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0091 - classifier_out_loss: 0.1798 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.9404 - decoder_out_accuracy: 0.9509 - val_loss: 0.0105 - val_classifier_out_loss: 0.2990 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.9098 - val_decoder_out_accuracy: 0.9505
# Epoch 32/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0091 - classifier_out_loss: 0.1752 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.9419 - decoder_out_accuracy: 0.9509 - val_loss: 0.0103 - val_classifier_out_loss: 0.2888 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9113 - val_decoder_out_accuracy: 0.9508
# Epoch 33/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0090 - classifier_out_loss: 0.1706 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.9434 - decoder_out_accuracy: 0.9509 - val_loss: 0.0105 - val_classifier_out_loss: 0.2998 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.9117 - val_decoder_out_accuracy: 0.9508
# Epoch 34/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0089 - classifier_out_loss: 0.1685 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.9445 - decoder_out_accuracy: 0.9510 - val_loss: 0.0105 - val_classifier_out_loss: 0.3085 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9117 - val_decoder_out_accuracy: 0.9504
# Epoch 35/100
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0089 - classifier_out_loss: 0.1661 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.9442 - decoder_out_accuracy: 0.9510 - val_loss: 0.0102 - val_classifier_out_loss: 0.2883 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9161 - val_decoder_out_accuracy: 0.9505
# Epoch 36/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0088 - classifier_out_loss: 0.1634 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.9451 - decoder_out_accuracy: 0.9510 - val_loss: 0.0104 - val_classifier_out_loss: 0.2967 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9137 - val_decoder_out_accuracy: 0.9511
# Epoch 37/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0088 - classifier_out_loss: 0.1597 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.9470 - decoder_out_accuracy: 0.9510 - val_loss: 0.0105 - val_classifier_out_loss: 0.3102 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9085 - val_decoder_out_accuracy: 0.9507
# Epoch 38/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0087 - classifier_out_loss: 0.1574 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.9469 - decoder_out_accuracy: 0.9510 - val_loss: 0.0104 - val_classifier_out_loss: 0.2986 - val_decoder_out_loss: 0.0074 - val_classifier_out_accuracy: 0.9123 - val_decoder_out_accuracy: 0.9504
# Epoch 39/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0087 - classifier_out_loss: 0.1516 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.9495 - decoder_out_accuracy: 0.9510 - val_loss: 0.0106 - val_classifier_out_loss: 0.3229 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.9062 - val_decoder_out_accuracy: 0.9504
# Epoch 40/100
# 1875/1875 [==============================] - 25s 14ms/step - loss: 0.0086 - classifier_out_loss: 0.1513 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.9497 - decoder_out_accuracy: 0.9510 - val_loss: 0.0105 - val_classifier_out_loss: 0.3168 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.9101 - val_decoder_out_accuracy: 0.9509
# Epoch 41/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0086 - classifier_out_loss: 0.1495 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.9489 - decoder_out_accuracy: 0.9510 - val_loss: 0.0104 - val_classifier_out_loss: 0.3097 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.9130 - val_decoder_out_accuracy: 0.9507
# Epoch 42/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0086 - classifier_out_loss: 0.1480 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.9506 - decoder_out_accuracy: 0.9510 - val_loss: 0.0104 - val_classifier_out_loss: 0.3137 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.9132 - val_decoder_out_accuracy: 0.9509
# Epoch 43/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0085 - classifier_out_loss: 0.1467 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.9509 - decoder_out_accuracy: 0.9511 - val_loss: 0.0102 - val_classifier_out_loss: 0.2962 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9143 - val_decoder_out_accuracy: 0.9506
# Epoch 44/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0085 - classifier_out_loss: 0.1435 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9509 - decoder_out_accuracy: 0.9511 - val_loss: 0.0103 - val_classifier_out_loss: 0.3099 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9145 - val_decoder_out_accuracy: 0.9507
# Epoch 45/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0084 - classifier_out_loss: 0.1405 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9525 - decoder_out_accuracy: 0.9511 - val_loss: 0.0104 - val_classifier_out_loss: 0.3226 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9084 - val_decoder_out_accuracy: 0.9510
# Epoch 46/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0084 - classifier_out_loss: 0.1367 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9539 - decoder_out_accuracy: 0.9511 - val_loss: 0.0103 - val_classifier_out_loss: 0.3131 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9134 - val_decoder_out_accuracy: 0.9509
# Epoch 47/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0083 - classifier_out_loss: 0.1341 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9545 - decoder_out_accuracy: 0.9511 - val_loss: 0.0105 - val_classifier_out_loss: 0.3318 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9066 - val_decoder_out_accuracy: 0.9506
# Epoch 48/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0083 - classifier_out_loss: 0.1332 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9547 - decoder_out_accuracy: 0.9511 - val_loss: 0.0105 - val_classifier_out_loss: 0.3261 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9083 - val_decoder_out_accuracy: 0.9506
# Epoch 49/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0083 - classifier_out_loss: 0.1349 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.9545 - decoder_out_accuracy: 0.9511 - val_loss: 0.0103 - val_classifier_out_loss: 0.3143 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9127 - val_decoder_out_accuracy: 0.9507
# Epoch 50/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0082 - classifier_out_loss: 0.1286 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9562 - decoder_out_accuracy: 0.9511 - val_loss: 0.0105 - val_classifier_out_loss: 0.3394 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9059 - val_decoder_out_accuracy: 0.9510
# Epoch 51/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0082 - classifier_out_loss: 0.1285 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9561 - decoder_out_accuracy: 0.9511 - val_loss: 0.0104 - val_classifier_out_loss: 0.3327 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9094 - val_decoder_out_accuracy: 0.9512
# Epoch 52/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0082 - classifier_out_loss: 0.1260 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9571 - decoder_out_accuracy: 0.9511 - val_loss: 0.0103 - val_classifier_out_loss: 0.3248 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9130 - val_decoder_out_accuracy: 0.9506
# Epoch 53/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0082 - classifier_out_loss: 0.1284 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9570 - decoder_out_accuracy: 0.9511 - val_loss: 0.0102 - val_classifier_out_loss: 0.3019 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.9195 - val_decoder_out_accuracy: 0.9512
# Epoch 54/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0081 - classifier_out_loss: 0.1240 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9576 - decoder_out_accuracy: 0.9512 - val_loss: 0.0103 - val_classifier_out_loss: 0.3227 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9137 - val_decoder_out_accuracy: 0.9508
# Epoch 55/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0081 - classifier_out_loss: 0.1232 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9579 - decoder_out_accuracy: 0.9512 - val_loss: 0.0103 - val_classifier_out_loss: 0.3202 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9183 - val_decoder_out_accuracy: 0.9509
# Epoch 56/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0081 - classifier_out_loss: 0.1205 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9585 - decoder_out_accuracy: 0.9512 - val_loss: 0.0102 - val_classifier_out_loss: 0.3136 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9170 - val_decoder_out_accuracy: 0.9509
# Epoch 57/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0081 - classifier_out_loss: 0.1199 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.9595 - decoder_out_accuracy: 0.9512 - val_loss: 0.0102 - val_classifier_out_loss: 0.3105 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9162 - val_decoder_out_accuracy: 0.9508
# Epoch 58/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0080 - classifier_out_loss: 0.1168 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9602 - decoder_out_accuracy: 0.9512 - val_loss: 0.0104 - val_classifier_out_loss: 0.3367 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9095 - val_decoder_out_accuracy: 0.9508
# Epoch 59/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0080 - classifier_out_loss: 0.1146 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9604 - decoder_out_accuracy: 0.9512 - val_loss: 0.0103 - val_classifier_out_loss: 0.3271 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9134 - val_decoder_out_accuracy: 0.9510
# Epoch 60/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0080 - classifier_out_loss: 0.1153 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9609 - decoder_out_accuracy: 0.9512 - val_loss: 0.0103 - val_classifier_out_loss: 0.3197 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9150 - val_decoder_out_accuracy: 0.9511
# Epoch 61/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1125 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9614 - decoder_out_accuracy: 0.9512 - val_loss: 0.0102 - val_classifier_out_loss: 0.3170 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9159 - val_decoder_out_accuracy: 0.9511
# Epoch 62/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1085 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9636 - decoder_out_accuracy: 0.9512 - val_loss: 0.0104 - val_classifier_out_loss: 0.3407 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9086 - val_decoder_out_accuracy: 0.9505
# Epoch 63/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1123 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9616 - decoder_out_accuracy: 0.9512 - val_loss: 0.0105 - val_classifier_out_loss: 0.3467 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9106 - val_decoder_out_accuracy: 0.9508
# Epoch 64/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1095 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9628 - decoder_out_accuracy: 0.9512 - val_loss: 0.0105 - val_classifier_out_loss: 0.3482 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9117 - val_decoder_out_accuracy: 0.9508
# Epoch 65/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1082 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9632 - decoder_out_accuracy: 0.9512 - val_loss: 0.0106 - val_classifier_out_loss: 0.3532 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.9071 - val_decoder_out_accuracy: 0.9512
# Epoch 66/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0079 - classifier_out_loss: 0.1105 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.9621 - decoder_out_accuracy: 0.9512 - val_loss: 0.0107 - val_classifier_out_loss: 0.3615 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9071 - val_decoder_out_accuracy: 0.9510
# Epoch 67/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0078 - classifier_out_loss: 0.1049 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9636 - decoder_out_accuracy: 0.9512 - val_loss: 0.0104 - val_classifier_out_loss: 0.3394 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9141 - val_decoder_out_accuracy: 0.9505
# Epoch 68/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0078 - classifier_out_loss: 0.1057 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9631 - decoder_out_accuracy: 0.9512 - val_loss: 0.0106 - val_classifier_out_loss: 0.3604 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9048 - val_decoder_out_accuracy: 0.9507
# Epoch 69/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0078 - classifier_out_loss: 0.1079 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9629 - decoder_out_accuracy: 0.9512 - val_loss: 0.0105 - val_classifier_out_loss: 0.3529 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9098 - val_decoder_out_accuracy: 0.9507
# Epoch 70/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0078 - classifier_out_loss: 0.1035 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9642 - decoder_out_accuracy: 0.9512 - val_loss: 0.0107 - val_classifier_out_loss: 0.3756 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9056 - val_decoder_out_accuracy: 0.9510
# Epoch 71/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0077 - classifier_out_loss: 0.1022 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9643 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3582 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9122 - val_decoder_out_accuracy: 0.9512
# Epoch 72/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0077 - classifier_out_loss: 0.0995 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9653 - decoder_out_accuracy: 0.9513 - val_loss: 0.0108 - val_classifier_out_loss: 0.3851 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.8997 - val_decoder_out_accuracy: 0.9508
# Epoch 73/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0077 - classifier_out_loss: 0.1010 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9652 - decoder_out_accuracy: 0.9513 - val_loss: 0.0107 - val_classifier_out_loss: 0.3659 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9073 - val_decoder_out_accuracy: 0.9506
# Epoch 74/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0077 - classifier_out_loss: 0.0986 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9656 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3566 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9125 - val_decoder_out_accuracy: 0.9507
# Epoch 75/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0966 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9666 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3639 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9149 - val_decoder_out_accuracy: 0.9508
# Epoch 76/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0077 - classifier_out_loss: 0.0999 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9650 - decoder_out_accuracy: 0.9513 - val_loss: 0.0110 - val_classifier_out_loss: 0.4077 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9038 - val_decoder_out_accuracy: 0.9509
# Epoch 77/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0976 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9660 - decoder_out_accuracy: 0.9513 - val_loss: 0.0110 - val_classifier_out_loss: 0.4068 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.9024 - val_decoder_out_accuracy: 0.9507
# Epoch 78/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0946 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9669 - decoder_out_accuracy: 0.9513 - val_loss: 0.0104 - val_classifier_out_loss: 0.3542 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9119 - val_decoder_out_accuracy: 0.9510
# Epoch 79/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0953 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.9671 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3634 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9126 - val_decoder_out_accuracy: 0.9507
# Epoch 80/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0928 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9673 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3731 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9120 - val_decoder_out_accuracy: 0.9509
# Epoch 81/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0932 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9677 - decoder_out_accuracy: 0.9513 - val_loss: 0.0104 - val_classifier_out_loss: 0.3506 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9158 - val_decoder_out_accuracy: 0.9507
# Epoch 82/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0076 - classifier_out_loss: 0.0920 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9676 - decoder_out_accuracy: 0.9513 - val_loss: 0.0107 - val_classifier_out_loss: 0.3810 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9135 - val_decoder_out_accuracy: 0.9508
# Epoch 83/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0910 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9686 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3694 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9124 - val_decoder_out_accuracy: 0.9507
# Epoch 84/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0904 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9682 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3750 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9102 - val_decoder_out_accuracy: 0.9510
# Epoch 85/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0880 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9698 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3666 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9159 - val_decoder_out_accuracy: 0.9508
# Epoch 86/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0900 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9683 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3793 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9090 - val_decoder_out_accuracy: 0.9508
# Epoch 87/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0904 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9679 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3639 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9143 - val_decoder_out_accuracy: 0.9508
# Epoch 88/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0859 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9698 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3791 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9114 - val_decoder_out_accuracy: 0.9508
# Epoch 89/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0877 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9691 - decoder_out_accuracy: 0.9513 - val_loss: 0.0108 - val_classifier_out_loss: 0.3932 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9080 - val_decoder_out_accuracy: 0.9508
# Epoch 90/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0075 - classifier_out_loss: 0.0881 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9691 - decoder_out_accuracy: 0.9513 - val_loss: 0.0107 - val_classifier_out_loss: 0.3807 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9096 - val_decoder_out_accuracy: 0.9506
# Epoch 91/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0844 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9699 - decoder_out_accuracy: 0.9513 - val_loss: 0.0111 - val_classifier_out_loss: 0.4257 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9070 - val_decoder_out_accuracy: 0.9509
# Epoch 92/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0834 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9707 - decoder_out_accuracy: 0.9513 - val_loss: 0.0105 - val_classifier_out_loss: 0.3693 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9138 - val_decoder_out_accuracy: 0.9512
# Epoch 93/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0836 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9704 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3768 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9118 - val_decoder_out_accuracy: 0.9508
# Epoch 94/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0838 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9701 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3775 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9118 - val_decoder_out_accuracy: 0.9506
# Epoch 95/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0811 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.9711 - decoder_out_accuracy: 0.9513 - val_loss: 0.0106 - val_classifier_out_loss: 0.3739 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9160 - val_decoder_out_accuracy: 0.9510
# Epoch 96/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0838 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.9703 - decoder_out_accuracy: 0.9514 - val_loss: 0.0105 - val_classifier_out_loss: 0.3698 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9150 - val_decoder_out_accuracy: 0.9509
# Epoch 97/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0810 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.9711 - decoder_out_accuracy: 0.9514 - val_loss: 0.0108 - val_classifier_out_loss: 0.3949 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.9099 - val_decoder_out_accuracy: 0.9509
# Epoch 98/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0073 - classifier_out_loss: 0.0803 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.9720 - decoder_out_accuracy: 0.9514 - val_loss: 0.0110 - val_classifier_out_loss: 0.4209 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9060 - val_decoder_out_accuracy: 0.9507
# Epoch 99/100
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0074 - classifier_out_loss: 0.0816 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.9715 - decoder_out_accuracy: 0.9514 - val_loss: 0.0107 - val_classifier_out_loss: 0.3906 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9134 - val_decoder_out_accuracy: 0.9511
# Epoch 100/100
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0073 - classifier_out_loss: 0.0811 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.9716 - decoder_out_accuracy: 0.9514 - val_loss: 0.0108 - val_classifier_out_loss: 0.3965 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.9136 - val_decoder_out_accuracy: 0.9506

# %%
model.encoder.save_weights('../weights/34_CAE4x16_encoder_epoch100.h5')
model.classifier.save_weights('../weights/34_CAE4x16_classifier_head_epoch100.h5')
model.decoder.save_weights('../weights/34_CAE4x16_decoder_head_epoch100.h5')

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axes[0].set_title('Reconstruction Loss')
axes[0].plot(history.history['decoder_out_loss'])
axes[0].plot(history.history['val_decoder_out_loss'])
axes[0].set_ylabel('MSE loss')
axes[0].set_xlabel('epoch')
axes[0].legend(['train', 'test'], loc='upper right')

axes[1].set_title('Classification Accuracy')
axes[1].plot(history.history['classifier_out_accuracy'])
axes[1].plot(history.history['val_classifier_out_accuracy'])
axes[1].set_ylabel('accuracy')
axes[1].set_xlabel('epoch')
axes[1].legend(['train', 'test'], loc='lower right')

fig.tight_layout()
# fig.show()
fig.savefig('../img/34/CE4x16_reco1_classify0.01.png')

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

n = 10
plt.figure(figsize=(19, 6))
for i in range(n):
    
    # predict
    x = x_test_split[i].reshape(1,16,14,14,1)
    z = model.encode(x, training=False)
    y = model.decode(z, training=False)
    
    ax = plt.subplot(3, n, i+1)
    plt.axis('off')
    plt.imshow(x_test_augmented[i].reshape(56,56))
    
    a = np.empty((8,8))
    for j in range(16):
        r = int(j/4)
        c = j%4
        a[r*2:(r+1)*2, c*2:(c+1)*2] = tf.reshape(z[j], (2,2))
    ax = plt.subplot(3, n, n+i+1) 
    plt.axis('off')
    plt.imshow(a)
    
    ax = plt.subplot(3, n, 2*n+i+1) 
    plt.axis('off')
    plt.imshow(tf.reshape(y, (56,56)))

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

z = model.encode(x_test_split[:1000], training=False)
y = model.classify(z, training=False)
n = 10
plt.figure(figsize=(19, 6))
for i in range(n):
    
    plt.subplot(1,n,i+1)
    plt.axis('off')
    plt.title("est: {:3.0f}\ntru: {:3.0f}".format(np.argmax(y[i]), np.argmax(y_test[i])))
    plt.imshow(x_test_augmented[i].reshape(56,56))
