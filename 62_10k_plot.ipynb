# %%
import numpy as np

data = np.load('/home/don/Desktop/CERN/BACHELOR/sw/toy_example/micae/python/data/CAE_10k_history.npy', allow_pickle=True)
history = data.item(0)

import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('CAE model')
plt.ylabel('loss (MSE)')
plt.ylim((0, 0.02))
plt.xlabel('epoch')
# plt.xlim((0, 50))
plt.legend(['train', 'test'], loc='upper right')
plt.grid(b=True, which='major', color='#666666', linestyle='-')
plt.savefig('../img/62/cae_loss.png', dpi=200)
