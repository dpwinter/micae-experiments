# %% [markdown]
# Use smaller filters for the encoder part while maintaining same 16 dimensions in dense layer.

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from skimage.transform import resize
from keras.utils import plot_model

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = resize(x_train, (x_train.shape[0], 32, 32, 1))
x_test = resize(x_test, (x_test.shape[0], 32, 32, 1))

# %%
import sys; sys.path.insert(0, '..')
import dataset

batch_size = 32
train_gen = dataset.BatchGenerator2(x_train, batch_size)
test_gen = dataset.BatchGenerator2(x_test, batch_size)

# %%
# model v3 with dense
model2 = tf.keras.Sequential(
    [
        tf.keras.layers.InputLayer(input_shape=(32,32,1), name='enc_in'),
        tf.keras.layers.Conv2D(filters=int(32), kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', use_bias=True, name='conv1'),
        tf.keras.layers.Conv2D(filters=int(64), kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', use_bias=True, name='conv2'),
        tf.keras.layers.Conv2D(filters=1, kernel_size=(1,1), strides=(1,1), activation='sigmoid', padding='valid', name='pt_conv'),
        tf.keras.layers.Flatten(name='latent'),
        tf.keras.layers.Dense(units=16, name='enc_dense'), # new dense
        
        tf.keras.layers.Dense(units=8*8*32, activation='relu', name='dense'),
        tf.keras.layers.Reshape(target_shape=(8, 8, 32), name='reshape'),
        tf.keras.layers.Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding='same', activation='relu', name='deconv1'),
        tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same', activation='relu', name='deconv2'),
        tf.keras.layers.Conv2DTranspose(filters=1, kernel_size=3, strides=1, padding='same', name='dec_out')
    ]
)
model2.compile(loss='mse', optimizer='adam')
# print(model2.summary())
plot_model(model2)

# %%
history = model2.fit(x_train, x_train, validation_data=(x_test, x_test), epochs=20)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0180 - val_loss: 0.0105
# Epoch 2/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 3/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 4/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 5/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 6/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0074 - val_loss: 0.0072
# Epoch 7/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0072 - val_loss: 0.0071
# Epoch 8/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 9/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0069 - val_loss: 0.0068
# Epoch 10/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0068 - val_loss: 0.0067
# Epoch 11/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 12/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 13/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 14/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 15/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 16/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 17/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 18/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 19/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 20/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0062 - val_loss: 0.0063

# %%
activation_model = tf.keras.models.Model(inputs=model2.input, outputs=[model2.get_layer('pt_conv').output, model2.output])

plt.figure(figsize=(20, 6))
n = 10
for i in range(n):
    out1, out = activation_model.predict(x_test[i].reshape(1,32,32,1))
    ax = plt.subplot(3, n, i+1)
    plt.imshow(x_test[i].reshape(32,32))
    
    ax = plt.subplot(3, n, n+i+1)
    #plt.imshow(out1.reshape(4,4))
    plt.imshow(out1.reshape(8,8))
    
    ax = plt.subplot(3, n, 2*n+i+1)
    plt.imshow(out.reshape(32,32))

# %%
from keras.models import Model
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation

# model v1 with dense
input_shape = (16,16,1)
latent_dim = 4

# shared layers
conv1  = Conv2D(filters=32, kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', name='conv1')
conv2  = Conv2D(filters=64, kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', name='conv2')
pt_conv = Conv2D(filters=1, kernel_size=(1,1), strides=(1,1), activation='sigmoid', padding='valid', name='pt_conv')
flat = Flatten()
#dense1 = Dense(units=4) # insert dense here: different setup.

inputs = [Input(shape=input_shape) for _ in range(4)]
outputs = []
for i in range(4):
    enc_out = flat(pt_conv(conv2(conv1(inputs[i]))))
    outputs.append(enc_out)
latent = concatenate(outputs, name="concatenate")
dense1 = Dense(units=16)(latent) # insert dense: this would be equivalent

# decoder
x = Dense(units=8*8*32, activation='relu', name='dense')(dense1)
x = Reshape(target_shape=(8, 8, 32), name='reshape')(x)
x = Conv2DTranspose(filters=64, kernel_size=3, strides=2, activation='relu', padding='same')(x)
x = Conv2DTranspose(filters=32, kernel_size=3, strides=2, activation='relu', padding='same')(x)
dec_out = Conv2DTranspose(filters=1, kernel_size=3, padding='same')(x)

model1 = Model(inputs, dec_out,)
model1.compile(loss='mse', optimizer='adam')
print(model1.summary())
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 8, 8, 32)     160         input_13[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 4, 4, 64)     8256        conv1[0][0]
#                                                                  conv1[1][0]
#                                                                  conv1[2][0]
#                                                                  conv1[3][0]
# __________________________________________________________________________________________________
# pt_conv (Conv2D)                (None, 4, 4, 1)      65          conv2[0][0]
#                                                                  conv2[1][0]
#                                                                  conv2[2][0]
#                                                                  conv2[3][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 16)           0           pt_conv[0][0]
#                                                                  pt_conv[1][0]
#                                                                  pt_conv[2][0]
#                                                                  pt_conv[3][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64)           0           flatten_3[0][0]
#                                                                  flatten_3[1][0]
#                                                                  flatten_3[2][0]
#                                                                  flatten_3[3][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           1040        concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         34816       dense_3[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 8, 8, 32)     0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 16, 16, 64)   18496       reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 32, 32, 32)   18464       conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 32, 32, 1)    289         conv2d_transpose_10[0][0]
# ==================================================================================================
# Total params: 81,586
# Trainable params: 81,586
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = model1.fit(train_gen, validation_data=test_gen, epochs=20)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0213 - val_loss: 0.0116
# Epoch 2/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0109 - val_loss: 0.0092
# Epoch 3/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 4/20
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 5/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0079 - val_loss: 0.0072
# Epoch 6/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 7/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 8/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 9/20
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0070 - val_loss: 0.0070
# Epoch 10/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 11/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 12/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 13/20
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 14/20
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 15/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 16/20
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 17/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 18/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 19/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 20/20
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0063 - val_loss: 0.0068

# %%
activation_model = tf.keras.models.Model(inputs=model1.input, outputs=[model1.get_layer('concatenate').output, model1.output])

plt.figure(figsize=(20, 6))
n = 10
for (xs,ys), i in zip(test_gen, range(n)):
    out1, out = activation_model.predict(xs)
    
    ax = plt.subplot(3, n, i+1)
    plt.imshow(ys[i].reshape(32,32))
    
#     ax = plt.subplot(3, n, n+i+1)
#     plt.imshow(out1[i].reshape(4,4))
    
    ax = plt.subplot(3, n, 2*n+i+1)
    plt.imshow(out[i].reshape(32,32))

# %% [markdown]
# Let's try adding a Dense at the end of each encoding unit

# %%
from keras.models import Model
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation
import tensorflow as tf

# model v1 with dense
input_shape = (16,16,1)
latent_dim = 4

# shared layers
conv1  = Conv2D(filters=32, kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', name='conv1')
conv2  = Conv2D(filters=64, kernel_size=(2,2), strides=(2,2), activation='relu', padding='valid', name='conv2')
pt_conv = Conv2D(filters=1, kernel_size=(1,1), strides=(1,1), activation='sigmoid', padding='valid', name='pt_conv')
flat = Flatten()
dense1 = Dense(units=4, name='dense1',  use_bias=True) # insert dense here: different setup.

inputs = [Input(shape=input_shape) for _ in range(4)]
outputs = []
for i in range(4):
    enc_out = dense1(flat(pt_conv(conv2(conv1(inputs[i])))))
    outputs.append(enc_out)
latent = concatenate(outputs, name="concatenate")
# dense1 = Dense(units=16)(latent) # insert dense: this would be equivalent

# decoder
x = Dense(units=8*8*32, activation='relu', name='dense')(latent)
x = Reshape(target_shape=(8, 8, 32), name='reshape')(x)
x = Conv2DTranspose(filters=64, kernel_size=3, strides=2, activation='relu', padding='same')(x)
x = Conv2DTranspose(filters=32, kernel_size=3, strides=2, activation='relu', padding='same')(x)
dec_out = Conv2DTranspose(filters=1, kernel_size=3, padding='same')(x)

model1 = Model(inputs, dec_out,)
model1.compile(loss='mse', optimizer='adam')
print(model1.summary())
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_29 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           [(None, 16, 16, 1)]  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 8, 8, 32)     160         input_29[0][0]
#                                                                  input_30[0][0]
#                                                                  input_31[0][0]
#                                                                  input_32[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 4, 4, 64)     8256        conv1[0][0]
#                                                                  conv1[1][0]
#                                                                  conv1[2][0]
#                                                                  conv1[3][0]
# __________________________________________________________________________________________________
# pt_conv (Conv2D)                (None, 4, 4, 1)      65          conv2[0][0]
#                                                                  conv2[1][0]
#                                                                  conv2[2][0]
#                                                                  conv2[3][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 16)           0           pt_conv[0][0]
#                                                                  pt_conv[1][0]
#                                                                  pt_conv[2][0]
#                                                                  pt_conv[3][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 4)            68          flatten_7[0][0]
#                                                                  flatten_7[1][0]
#                                                                  flatten_7[2][0]
#                                                                  flatten_7[3][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16)           0           dense1[0][0]
#                                                                  dense1[1][0]
#                                                                  dense1[2][0]
#                                                                  dense1[3][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2048)         34816       concatenate[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 8, 8, 32)     0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 16, 16, 64)   18496       reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 32, 32, 32)   18464       conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 32, 32, 1)    289         conv2d_transpose_22[0][0]
# ==================================================================================================
# Total params: 80,614
# Trainable params: 80,614
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = model1.fit(train_gen, validation_data=test_gen, epochs=30)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0215 - val_loss: 0.0141
# Epoch 2/30
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0130 - val_loss: 0.0117
# Epoch 3/30
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0115 - val_loss: 0.0108
# Epoch 4/30
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 5/30
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 6/30
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0100 - val_loss: 0.0096
# Epoch 7/30
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.0097 - val_loss: 0.0094
# Epoch 8/30
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0095 - val_loss: 0.0093
# Epoch 9/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0093 - val_loss: 0.0092
# Epoch 10/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 11/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 12/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 13/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 14/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 15/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 16/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 17/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 18/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 19/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 20/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 21/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 22/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 23/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 24/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 25/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 26/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 27/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 28/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 29/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 30/30
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0080 - val_loss: 0.0081

# %%
activation_model = tf.keras.models.Model(inputs=model1.input, outputs=[model1.get_layer('concatenate').output, model1.output])

plt.figure(figsize=(20, 6))
n = 10
for (xs,ys), i in zip(test_gen, range(n)):
    out1, out = activation_model.predict(xs)
    
    ax = plt.subplot(3, n, i+1)
    plt.imshow(ys[i].reshape(32,32))
    
#     ax = plt.subplot(3, n, n+i+1)
#     plt.imshow(out1[i].reshape(4,4))
    
    ax = plt.subplot(3, n, 2*n+i+1)
    plt.imshow(out[i].reshape(32,32))
