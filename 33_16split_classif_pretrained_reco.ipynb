# %% [markdown]
# Train 16-split classifier on pretrained encoder (pretrained on reconstruction). Here we use only model 1 from E32, because of the worse classification results for model 2.

# %%
import sys; sys.path.insert(0, '..')
import utils
import keras
import numpy as np

def embed_and_translate(data, nrows, ncols):
    ndata = np.zeros((len(data), nrows, ncols, 1), dtype='float32')
    translations = np.empty((len(data), 2), dtype='float32')
    width, height = data.shape[1], data.shape[2]
    for i in range(len(data)):
        x = np.random.randint(ncols-width)
        y = np.random.randint(nrows-height)
        ndata[i][x:x+width, y:y+height] = data[i] # rows, cols = height, width
        translations[i][0] = x+(width//2)
        translations[i][1] = y+(height//2)
    return ndata, translations
            
n_splits = 16
io_shape = (56,56,1)
size = int(io_shape[0] // (n_splits**(1/2)))
latent_dim = 16 * 4 # since we have 4x4-splits we need 4 times the latent space for a fair comparison.

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255.
x_train_augmented, _ = embed_and_translate(x_train, 56, 56)
x_train_split = np.array([utils.split(x, size, size) for x in x_train_augmented], dtype='float32')
y_train = keras.utils.to_categorical(y_train)

x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test = x_test.astype('float32') / 255.
x_test_augmented, _ = embed_and_translate(x_test, 56, 56)
x_test_split = np.array([utils.split(x, size, size) for x in x_test_augmented], dtype='float32')
y_test = keras.utils.to_categorical(y_test)

# %% [markdown]
# After pretraining much worse classification results. Accuracy of ~78%

# %%
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation, Dropout
from keras import Sequential
from keras.models import Model

import tensorflow as tf
import keras
import sys; sys.path.insert(0, '..')
import utils

class MultiSplit(Model):
    def __init__(self, n_splits, latent_dim, io_shape):
        super(MultiSplit, self).__init__()
        n_filters = [32, 64]
        size = int( io_shape[0] // (n_splits**(1/2)) )  # W = H
        self.encoder = self._create_encoder(latent_dim//n_splits, (size, size,1), n_filters)
        self.input_reshaper = utils.Reshaper((n_splits, size, size, 1), (size, size,1))
        self.latent_reshaper = utils.Reshaper([latent_dim//n_splits], [latent_dim])
        self.classifier = self._create_classifier(latent_dim)
#         self.decoder = self._create_decoder(latent_dim, io_shape, n_filters)
        
    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            y_pred = self(x)
            loss = self.compiled_loss(y, y_pred)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def test_step(self, data):
        x, y = data
        y_pred = self(x, training=False)
        self.compiled_loss(y, y_pred)
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, x, training=True):
        z = self.encode(x, training=training)
#         y_pred = self.decode(z ,training=training)
        y_pred = self.classify(z ,training=training)
#         y_pred = self.regress(z ,training=training)
        return y_pred
        
    def encode(self, x, training=True):
        return self.encoder( self.input_reshaper(x) , training)
    
    def decode(self, z, training=True):
        return self.decoder( self.latent_reshaper(z) , training)
    
    def classify(self, z, training=True):
        return self.classifier( self.latent_reshaper(z) , training)
    
    def _create_encoder(self, latent_dim, input_shape, n_filters):
        return Sequential([
            Input(shape=input_shape),
            Conv2D(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2D(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Flatten(),
            Dense(units=latent_dim, activation='sigmoid')
        ], name='encoder')

    def _create_decoder(self, latent_dim, io_shape, n_filters):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(io_shape[0]//4 * io_shape[1]//4 * 8),
            Reshape((io_shape[0]//4, io_shape[1]//4, 8)),
            Conv2DTranspose(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=1, kernel_size=(3,3), padding='same'),
            Activation('sigmoid', name='decoder_out')
        ])
    
    def _create_classifier(self, latent_dim):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(64, activation='relu'),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax')
        ])

# %%
model = MultiSplit(n_splits, latent_dim, io_shape)

model.encoder.load_weights('../weights/30_CE4x16_epoch50.h5')
for layer in model.encoder.layers:
    layer.trainable = False
    
model.compile(loss='categorical_crossentropy', metrics=['acc'], optimizer='adam') # COMPILE AFTER WEIGHTS LOADED

history = model.fit(x_train_split, y_train, validation_data=(x_test_split, y_test), epochs=100, batch_size=32)

import matplotlib.pyplot as plt
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('16-split (pretrained) classification accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()
plt.savefig('../img/33/CE4x16_epoch50.png')
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.9641 - acc: 0.2853 - val_loss: 1.6892 - val_acc: 0.4018
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.5274 - acc: 0.4561 - val_loss: 1.3921 - val_acc: 0.5056
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3265 - acc: 0.5297 - val_loss: 1.3295 - val_acc: 0.5251
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.2139 - acc: 0.5714 - val_loss: 1.1572 - val_acc: 0.5904
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.1345 - acc: 0.5983 - val_loss: 1.1165 - val_acc: 0.6093
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0725 - acc: 0.6208 - val_loss: 1.0494 - val_acc: 0.6283
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0224 - acc: 0.6379 - val_loss: 1.0140 - val_acc: 0.6392
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9872 - acc: 0.6502 - val_loss: 0.9937 - val_acc: 0.6483
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.9562 - acc: 0.6625 - val_loss: 0.9420 - val_acc: 0.6698
# Epoch 10/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.9317 - acc: 0.6720 - val_loss: 0.9730 - val_acc: 0.6607
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.9090 - acc: 0.6778 - val_loss: 0.9305 - val_acc: 0.6702
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8887 - acc: 0.6862 - val_loss: 0.8848 - val_acc: 0.6958
# Epoch 13/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8702 - acc: 0.6931 - val_loss: 0.9202 - val_acc: 0.6811
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8543 - acc: 0.6999 - val_loss: 0.8717 - val_acc: 0.6952
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8388 - acc: 0.7046 - val_loss: 0.8659 - val_acc: 0.6997
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8293 - acc: 0.7080 - val_loss: 0.8907 - val_acc: 0.6933
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8146 - acc: 0.7143 - val_loss: 0.8404 - val_acc: 0.7085
# Epoch 18/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.8039 - acc: 0.7179 - val_loss: 0.8328 - val_acc: 0.7143
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7936 - acc: 0.7211 - val_loss: 0.8486 - val_acc: 0.7120
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7853 - acc: 0.7231 - val_loss: 0.8118 - val_acc: 0.7178
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7777 - acc: 0.7280 - val_loss: 0.8007 - val_acc: 0.7226
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7680 - acc: 0.7309 - val_loss: 0.7907 - val_acc: 0.7338
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7622 - acc: 0.7330 - val_loss: 0.7839 - val_acc: 0.7291
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7545 - acc: 0.7354 - val_loss: 0.8225 - val_acc: 0.7188
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7444 - acc: 0.7380 - val_loss: 0.7895 - val_acc: 0.7270
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7417 - acc: 0.7405 - val_loss: 0.7835 - val_acc: 0.7300
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7344 - acc: 0.7420 - val_loss: 0.7679 - val_acc: 0.7313
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7260 - acc: 0.7452 - val_loss: 0.7819 - val_acc: 0.7265
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7231 - acc: 0.7466 - val_loss: 0.7451 - val_acc: 0.7415
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7132 - acc: 0.7499 - val_loss: 0.7816 - val_acc: 0.7355
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7112 - acc: 0.7518 - val_loss: 0.7705 - val_acc: 0.7347
# Epoch 32/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7044 - acc: 0.7536 - val_loss: 0.7454 - val_acc: 0.7443
# Epoch 33/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6990 - acc: 0.7548 - val_loss: 0.7547 - val_acc: 0.7418
# Epoch 34/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6953 - acc: 0.7562 - val_loss: 0.7719 - val_acc: 0.7354
# Epoch 35/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6911 - acc: 0.7572 - val_loss: 0.7508 - val_acc: 0.7432
# Epoch 36/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6863 - acc: 0.7605 - val_loss: 0.7506 - val_acc: 0.7401
# Epoch 37/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6838 - acc: 0.7607 - val_loss: 0.7573 - val_acc: 0.7384
# Epoch 38/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6759 - acc: 0.7621 - val_loss: 0.7297 - val_acc: 0.7498
# Epoch 39/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6727 - acc: 0.7647 - val_loss: 0.7377 - val_acc: 0.7482
# Epoch 40/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6704 - acc: 0.7664 - val_loss: 0.7369 - val_acc: 0.7518
# Epoch 41/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6650 - acc: 0.7666 - val_loss: 0.7294 - val_acc: 0.7514
# Epoch 42/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6626 - acc: 0.7681 - val_loss: 0.7265 - val_acc: 0.7545
# Epoch 43/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6600 - acc: 0.7694 - val_loss: 0.7280 - val_acc: 0.7511
# Epoch 44/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6556 - acc: 0.7710 - val_loss: 0.7362 - val_acc: 0.7472
# Epoch 45/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6542 - acc: 0.7713 - val_loss: 0.7289 - val_acc: 0.7506
# Epoch 46/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6499 - acc: 0.7725 - val_loss: 0.7269 - val_acc: 0.7547
# Epoch 47/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6475 - acc: 0.7733 - val_loss: 0.7175 - val_acc: 0.7548
# Epoch 48/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6450 - acc: 0.7740 - val_loss: 0.7486 - val_acc: 0.7438
# Epoch 49/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6397 - acc: 0.7770 - val_loss: 0.7010 - val_acc: 0.7657
# Epoch 50/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6386 - acc: 0.7769 - val_loss: 0.7243 - val_acc: 0.7528
# Epoch 51/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6343 - acc: 0.7776 - val_loss: 0.7417 - val_acc: 0.7483
# Epoch 52/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6335 - acc: 0.7776 - val_loss: 0.7073 - val_acc: 0.7593
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6287 - acc: 0.7815 - val_loss: 0.7070 - val_acc: 0.7590
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6277 - acc: 0.7811 - val_loss: 0.7484 - val_acc: 0.7454
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6265 - acc: 0.7810 - val_loss: 0.7005 - val_acc: 0.7636
# Epoch 56/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6244 - acc: 0.7823 - val_loss: 0.6925 - val_acc: 0.7634
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6228 - acc: 0.7824 - val_loss: 0.7030 - val_acc: 0.7587
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6205 - acc: 0.7835 - val_loss: 0.6936 - val_acc: 0.7620
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6159 - acc: 0.7850 - val_loss: 0.6999 - val_acc: 0.7553
# Epoch 60/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6165 - acc: 0.7845 - val_loss: 0.7160 - val_acc: 0.7587
# Epoch 61/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6152 - acc: 0.7860 - val_loss: 0.7055 - val_acc: 0.7610
# Epoch 62/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6128 - acc: 0.7853 - val_loss: 0.7210 - val_acc: 0.7587
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6105 - acc: 0.7865 - val_loss: 0.7062 - val_acc: 0.7588
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6067 - acc: 0.7883 - val_loss: 0.6927 - val_acc: 0.7627
# Epoch 65/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6094 - acc: 0.7880 - val_loss: 0.6936 - val_acc: 0.7633
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6062 - acc: 0.7890 - val_loss: 0.7088 - val_acc: 0.7610
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6025 - acc: 0.7884 - val_loss: 0.6779 - val_acc: 0.7736
# Epoch 68/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6003 - acc: 0.7921 - val_loss: 0.6802 - val_acc: 0.7717
# Epoch 69/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6020 - acc: 0.7891 - val_loss: 0.7015 - val_acc: 0.7602
# Epoch 70/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5973 - acc: 0.7915 - val_loss: 0.7092 - val_acc: 0.7550
# Epoch 71/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5970 - acc: 0.7918 - val_loss: 0.6851 - val_acc: 0.7712
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5964 - acc: 0.7924 - val_loss: 0.7288 - val_acc: 0.7488
# Epoch 73/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5950 - acc: 0.7923 - val_loss: 0.6890 - val_acc: 0.7659
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5915 - acc: 0.7951 - val_loss: 0.6969 - val_acc: 0.7699
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5906 - acc: 0.7941 - val_loss: 0.6937 - val_acc: 0.7639
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5887 - acc: 0.7948 - val_loss: 0.7068 - val_acc: 0.7607
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5879 - acc: 0.7946 - val_loss: 0.6858 - val_acc: 0.7695
# Epoch 78/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5869 - acc: 0.7954 - val_loss: 0.6924 - val_acc: 0.7665
# Epoch 79/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5851 - acc: 0.7959 - val_loss: 0.6953 - val_acc: 0.7677
# Epoch 80/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5837 - acc: 0.7966 - val_loss: 0.7101 - val_acc: 0.7583
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5834 - acc: 0.7959 - val_loss: 0.6840 - val_acc: 0.7700
# Epoch 82/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5843 - acc: 0.7961 - val_loss: 0.6909 - val_acc: 0.7628
# Epoch 83/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5813 - acc: 0.7984 - val_loss: 0.6619 - val_acc: 0.7765
# Epoch 84/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5794 - acc: 0.7988 - val_loss: 0.6620 - val_acc: 0.7764
# Epoch 85/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5807 - acc: 0.7979 - val_loss: 0.6680 - val_acc: 0.7732
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5755 - acc: 0.8013 - val_loss: 0.6637 - val_acc: 0.7739
# Epoch 87/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5753 - acc: 0.8000 - val_loss: 0.6872 - val_acc: 0.7668
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5759 - acc: 0.7998 - val_loss: 0.7189 - val_acc: 0.7587
# Epoch 89/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5736 - acc: 0.8002 - val_loss: 0.6787 - val_acc: 0.7660
# Epoch 90/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5723 - acc: 0.8001 - val_loss: 0.6899 - val_acc: 0.7684
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5726 - acc: 0.8014 - val_loss: 0.6780 - val_acc: 0.7742
# Epoch 92/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5716 - acc: 0.8001 - val_loss: 0.6566 - val_acc: 0.7802
# Epoch 93/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5698 - acc: 0.8013 - val_loss: 0.6964 - val_acc: 0.7653
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5683 - acc: 0.8025 - val_loss: 0.6767 - val_acc: 0.7732
# Epoch 95/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5684 - acc: 0.8033 - val_loss: 0.6686 - val_acc: 0.7746
# Epoch 96/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5664 - acc: 0.8031 - val_loss: 0.6824 - val_acc: 0.7690
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5650 - acc: 0.8037 - val_loss: 0.6964 - val_acc: 0.7670
# Epoch 98/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5667 - acc: 0.8015 - val_loss: 0.6714 - val_acc: 0.7732
# Epoch 99/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5636 - acc: 0.8032 - val_loss: 0.6647 - val_acc: 0.7774
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5621 - acc: 0.8047 - val_loss: 0.6796 - val_acc: 0.7726

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import random

n = 10
ints = [random.randint(0, len(x_test_split)) for _ in range(n)]
x_inputs = np.array([x_test_split[i] for i in ints], dtype='float32')
y_truths = [y_test[i] for i in ints]
x_truths = [x_test_augmented[i] for i in ints]

z = model.encode(x_inputs, training=False)
y = model.classify(z, training=False)
plt.figure(figsize=(19, 6))
for i in range(n):
    
    plt.subplot(1,n,i+1)
    plt.axis('off')
    plt.title("est: {:3.0f}\ntru: {:3.0f}".format(np.argmax(y[i]), np.argmax(y_truths[i])))
    plt.imshow(x_truths[i].reshape(56,56))
