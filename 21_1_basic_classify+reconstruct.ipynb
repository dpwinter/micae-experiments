# %% [markdown]
# # Training with two losses (reco+class) generally leads to worse performance than pretrain, fix weights and train classifier

# %%
from keras.layers import Flatten, Conv2D, Conv2DTranspose, Dense, Input, Reshape, concatenate, Activation
from keras import Sequential
from keras.models import Model

import tensorflow as tf
import keras
import sys; sys.path.insert(0, '..')
import utils

class MultiSplit(Model):
    def __init__(self, n_splits, latent_dim, io_shape):
        super(MultiSplit, self).__init__()
        n_filters = [32, 64]
        size = int( io_shape[0] // (n_splits**(1/2)) )  # W = H
        self.encoder = self._create_encoder(latent_dim//n_splits, (size, size,1), n_filters)
        self.input_reshaper = utils.Reshaper((n_splits, size, size, 1), (size, size,1))
        self.latent_reshaper = utils.Reshaper([latent_dim//n_splits], [latent_dim])
        self.classifier = self._create_classifier(latent_dim)
        self.decoder = self._create_decoder(latent_dim, io_shape, n_filters)
        
    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            y_pred = self(x)
            loss = self.compiled_loss(y, y_pred)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def test_step(self, data):
        x, y = data
        y_pred = self(x, training=False)
        self.compiled_loss(y, y_pred)
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, x, training=True):
        z = self.encode(x, training=training)
        y_reco  = self.decode(z ,training=training)
        y_class = self.classify(z, training=training)
        return {'decoder_out': y_reco, 'classifier_out': y_class}
        
    def encode(self, x, training=True):
        return self.encoder( self.input_reshaper(x) , training)
    
    def decode(self, z, training=True):
        return self.decoder( self.latent_reshaper(z) , training)
    
    def classify(self, z, training=True):
        return self.classifier( self.latent_reshaper(z) , training)
    
    def _create_encoder(self, latent_dim, input_shape, n_filters):
        return Sequential([
            Input(shape=input_shape),
            Conv2D(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2D(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Flatten(),
            Dense(units=latent_dim)
        ], name='encoder')

    def _create_decoder(self, latent_dim, io_shape, n_filters):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(io_shape[0]//4 * io_shape[1]//4 * n_filters[0]),  # factor 4 due to conv.
            Reshape((io_shape[0]//4, io_shape[1]//4, n_filters[0])),
            Conv2DTranspose(filters=n_filters[1], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=n_filters[0], kernel_size=(3,3), strides=(2,2), activation='relu', padding='same'),
            Conv2DTranspose(filters=1, kernel_size=(3,3), padding='same'),
            Activation('sigmoid', name='decoder_out')
        ])
    
    def _create_classifier(self, latent_dim):
        return Sequential([
            Input(shape=(latent_dim)),
            Dense(16, activation='relu'),
            Dense(16, activation='relu'),
            Dense(10, name='classfier_out', activation='softmax')
        ])

# %% [markdown]
# 1-split, verify performance for classifier loss weight=0

# %%
import keras
import numpy as np

n_splits = 1
io_shape = (28,28,1)
size = int(io_shape[0] // (n_splits**(1/2)))
latent_dim = 16

model = MultiSplit(n_splits, latent_dim, io_shape)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255.
x_train_split = np.array([utils.split(x, size, size) for x in x_train], dtype='float32')
y_train = keras.utils.to_categorical(y_train)

x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test = x_test.astype('float32') / 255.
x_test_split = np.array([utils.split(x, size, size) for x in x_test], dtype='float32')
y_test = keras.utils.to_categorical(y_test)
print(x_test_split.shape)
# Out:
# (10000, 1, 28, 28, 1)

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.0
}
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train, 'classifier_out': y_train},
                    validation_data=(x_test_split, {'decoder_out': x_test, 'classifier_out': y_test}),
                    epochs=25, batch_size=32)

import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axes[0].set_title('Reconstruction Loss')
axes[0].plot(history.history['decoder_out_loss'])
axes[0].plot(history.history['val_decoder_out_loss'])
axes[0].set_ylabel('MSE loss')
axes[0].set_xlabel('epoch')
axes[0].legend(['train', 'test'], loc='upper right')

axes[1].set_title('Classification Accuracy')
axes[1].plot(history.history['classifier_out_accuracy'])
axes[1].plot(history.history['val_classifier_out_accuracy'])
axes[1].set_ylabel('CEE loss')
axes[1].set_xlabel('epoch')
axes[1].legend(['train', 'test'], loc='lower right')

fig.tight_layout()
fig.show()
fig.savefig('../img/21/CE16_reco1_classify0.png')
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0218 - classifier_out_loss: 3.8209 - decoder_out_loss: 0.0218 - classifier_out_accuracy: 0.0876 - decoder_out_accuracy: 0.8104 - val_loss: 0.0109 - val_classifier_out_loss: 3.6948 - val_decoder_out_loss: 0.0109 - val_classifier_out_accuracy: 0.0776 - val_decoder_out_accuracy: 0.8122
# Epoch 2/25
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0102 - classifier_out_loss: 3.5082 - decoder_out_loss: 0.0102 - classifier_out_accuracy: 0.0796 - decoder_out_accuracy: 0.8135 - val_loss: 0.0093 - val_classifier_out_loss: 3.4150 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.0746 - val_decoder_out_accuracy: 0.8127
# Epoch 3/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0091 - classifier_out_loss: 3.2885 - decoder_out_loss: 0.0091 - classifier_out_accuracy: 0.0787 - decoder_out_accuracy: 0.8139 - val_loss: 0.0086 - val_classifier_out_loss: 3.1957 - val_decoder_out_loss: 0.0086 - val_classifier_out_accuracy: 0.0756 - val_decoder_out_accuracy: 0.8131
# Epoch 4/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0085 - classifier_out_loss: 3.0941 - decoder_out_loss: 0.0085 - classifier_out_accuracy: 0.0786 - decoder_out_accuracy: 0.8141 - val_loss: 0.0082 - val_classifier_out_loss: 2.9922 - val_decoder_out_loss: 0.0082 - val_classifier_out_accuracy: 0.0751 - val_decoder_out_accuracy: 0.8131
# Epoch 5/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0081 - classifier_out_loss: 2.9334 - decoder_out_loss: 0.0081 - classifier_out_accuracy: 0.0790 - decoder_out_accuracy: 0.8142 - val_loss: 0.0081 - val_classifier_out_loss: 2.8622 - val_decoder_out_loss: 0.0081 - val_classifier_out_accuracy: 0.0758 - val_decoder_out_accuracy: 0.8133
# Epoch 6/25
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0078 - classifier_out_loss: 2.8195 - decoder_out_loss: 0.0078 - classifier_out_accuracy: 0.0784 - decoder_out_accuracy: 0.8143 - val_loss: 0.0078 - val_classifier_out_loss: 2.8008 - val_decoder_out_loss: 0.0078 - val_classifier_out_accuracy: 0.0768 - val_decoder_out_accuracy: 0.8133
# Epoch 7/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0076 - classifier_out_loss: 2.7344 - decoder_out_loss: 0.0076 - classifier_out_accuracy: 0.0782 - decoder_out_accuracy: 0.8143 - val_loss: 0.0076 - val_classifier_out_loss: 2.7161 - val_decoder_out_loss: 0.0076 - val_classifier_out_accuracy: 0.0742 - val_decoder_out_accuracy: 0.8133
# Epoch 8/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0075 - classifier_out_loss: 2.6596 - decoder_out_loss: 0.0075 - classifier_out_accuracy: 0.0779 - decoder_out_accuracy: 0.8144 - val_loss: 0.0075 - val_classifier_out_loss: 2.6430 - val_decoder_out_loss: 0.0075 - val_classifier_out_accuracy: 0.0744 - val_decoder_out_accuracy: 0.8134
# Epoch 9/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0073 - classifier_out_loss: 2.6053 - decoder_out_loss: 0.0073 - classifier_out_accuracy: 0.0775 - decoder_out_accuracy: 0.8144 - val_loss: 0.0073 - val_classifier_out_loss: 2.5884 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.0723 - val_decoder_out_accuracy: 0.8134
# Epoch 10/25
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0072 - classifier_out_loss: 2.5629 - decoder_out_loss: 0.0072 - classifier_out_accuracy: 0.0762 - decoder_out_accuracy: 0.8145 - val_loss: 0.0073 - val_classifier_out_loss: 2.5525 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.0729 - val_decoder_out_accuracy: 0.8134
# Epoch 11/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0071 - classifier_out_loss: 2.5288 - decoder_out_loss: 0.0071 - classifier_out_accuracy: 0.0764 - decoder_out_accuracy: 0.8145 - val_loss: 0.0073 - val_classifier_out_loss: 2.5217 - val_decoder_out_loss: 0.0073 - val_classifier_out_accuracy: 0.0720 - val_decoder_out_accuracy: 0.8134
# Epoch 12/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0070 - classifier_out_loss: 2.5024 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.0758 - decoder_out_accuracy: 0.8145 - val_loss: 0.0071 - val_classifier_out_loss: 2.5028 - val_decoder_out_loss: 0.0071 - val_classifier_out_accuracy: 0.0713 - val_decoder_out_accuracy: 0.8134
# Epoch 13/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0070 - classifier_out_loss: 2.4823 - decoder_out_loss: 0.0070 - classifier_out_accuracy: 0.0758 - decoder_out_accuracy: 0.8145 - val_loss: 0.0072 - val_classifier_out_loss: 2.4836 - val_decoder_out_loss: 0.0072 - val_classifier_out_accuracy: 0.0709 - val_decoder_out_accuracy: 0.8135
# Epoch 14/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0069 - classifier_out_loss: 2.4672 - decoder_out_loss: 0.0069 - classifier_out_accuracy: 0.0757 - decoder_out_accuracy: 0.8145 - val_loss: 0.0070 - val_classifier_out_loss: 2.4638 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.0714 - val_decoder_out_accuracy: 0.8135
# Epoch 15/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0068 - classifier_out_loss: 2.4515 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.0759 - decoder_out_accuracy: 0.8146 - val_loss: 0.0070 - val_classifier_out_loss: 2.4602 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.0712 - val_decoder_out_accuracy: 0.8135
# Epoch 16/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0068 - classifier_out_loss: 2.4406 - decoder_out_loss: 0.0068 - classifier_out_accuracy: 0.0762 - decoder_out_accuracy: 0.8146 - val_loss: 0.0070 - val_classifier_out_loss: 2.4450 - val_decoder_out_loss: 0.0070 - val_classifier_out_accuracy: 0.0721 - val_decoder_out_accuracy: 0.8135
# Epoch 17/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0067 - classifier_out_loss: 2.4313 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.0762 - decoder_out_accuracy: 0.8146 - val_loss: 0.0069 - val_classifier_out_loss: 2.4335 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.0725 - val_decoder_out_accuracy: 0.8135
# Epoch 18/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0067 - classifier_out_loss: 2.4237 - decoder_out_loss: 0.0067 - classifier_out_accuracy: 0.0758 - decoder_out_accuracy: 0.8146 - val_loss: 0.0069 - val_classifier_out_loss: 2.4349 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.0702 - val_decoder_out_accuracy: 0.8134
# Epoch 19/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0066 - classifier_out_loss: 2.4166 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.0756 - decoder_out_accuracy: 0.8146 - val_loss: 0.0069 - val_classifier_out_loss: 2.4256 - val_decoder_out_loss: 0.0069 - val_classifier_out_accuracy: 0.0711 - val_decoder_out_accuracy: 0.8135
# Epoch 20/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0066 - classifier_out_loss: 2.4122 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.0757 - decoder_out_accuracy: 0.8146 - val_loss: 0.0068 - val_classifier_out_loss: 2.4187 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0695 - val_decoder_out_accuracy: 0.8134
# Epoch 21/25
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0066 - classifier_out_loss: 2.4064 - decoder_out_loss: 0.0066 - classifier_out_accuracy: 0.0757 - decoder_out_accuracy: 0.8146 - val_loss: 0.0068 - val_classifier_out_loss: 2.4135 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0698 - val_decoder_out_accuracy: 0.8134
# Epoch 22/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0065 - classifier_out_loss: 2.4016 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.0756 - decoder_out_accuracy: 0.8146 - val_loss: 0.0068 - val_classifier_out_loss: 2.4098 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0716 - val_decoder_out_accuracy: 0.8134
# Epoch 23/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0065 - classifier_out_loss: 2.3987 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.0752 - decoder_out_accuracy: 0.8146 - val_loss: 0.0068 - val_classifier_out_loss: 2.4085 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0688 - val_decoder_out_accuracy: 0.8134
# Epoch 24/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0065 - classifier_out_loss: 2.3951 - decoder_out_loss: 0.0065 - classifier_out_accuracy: 0.0756 - decoder_out_accuracy: 0.8146 - val_loss: 0.0068 - val_classifier_out_loss: 2.4069 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0671 - val_decoder_out_accuracy: 0.8135
# Epoch 25/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0064 - classifier_out_loss: 2.3919 - decoder_out_loss: 0.0064 - classifier_out_accuracy: 0.0755 - decoder_out_accuracy: 0.8147 - val_loss: 0.0068 - val_classifier_out_loss: 2.4010 - val_decoder_out_loss: 0.0068 - val_classifier_out_accuracy: 0.0696 - val_decoder_out_accuracy: 0.8136
# <ipython-input-3-0196e6808182>:33: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# 4-split, verify performance for classifier loss weight=0

# %%
import keras
import numpy as np

n_splits = 4
io_shape = (28,28,1)
size = int(io_shape[0] // (n_splits**(1/2)))
latent_dim = 16

model = MultiSplit(n_splits, latent_dim, io_shape)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_train = x_train.astype('float32') / 255.
x_train_split = np.array([utils.split(x, size, size) for x in x_train], dtype='float32')
y_train = keras.utils.to_categorical(y_train)

x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_test = x_test.astype('float32') / 255.
x_test_split = np.array([utils.split(x, size, size) for x in x_test], dtype='float32')
y_test = keras.utils.to_categorical(y_test)
print(x_test_split.shape)
# Out:
# (10000, 4, 14, 14, 1)

# %%
losses = {
    'decoder_out' : 'mse',
    'classifier_out' : 'categorical_crossentropy'
}
loss_weights = {
    'decoder_out' : 1.0,
    'classifier_out' : 0.0
}
model.compile(loss=losses, loss_weights=loss_weights, optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train_split, {'decoder_out': x_train, 'classifier_out': y_train},
                    validation_data=(x_test_split, {'decoder_out': x_test, 'classifier_out': y_test}),
                    epochs=25, batch_size=32)

import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
axes[0].set_title('Reconstruction Loss')
axes[0].plot(history.history['decoder_out_loss'])
axes[0].plot(history.history['val_decoder_out_loss'])
axes[0].set_ylabel('MSE loss')
axes[0].set_xlabel('epoch')
axes[0].legend(['train', 'test'], loc='upper right')

axes[1].set_title('Classification Accuracy')
axes[1].plot(history.history['classifier_out_accuracy'])
axes[1].plot(history.history['val_classifier_out_accuracy'])
axes[1].set_ylabel('CEE loss')
axes[1].set_xlabel('epoch')
axes[1].legend(['train', 'test'], loc='lower right')

fig.tight_layout()
fig.show()
fig.savefig('../img/21/CE4x4_reco1_classify0.png')
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0240 - classifier_out_loss: 3.1905 - decoder_out_loss: 0.0240 - classifier_out_accuracy: 0.1492 - decoder_out_accuracy: 0.8090 - val_loss: 0.0143 - val_classifier_out_loss: 3.0793 - val_decoder_out_loss: 0.0143 - val_classifier_out_accuracy: 0.1632 - val_decoder_out_accuracy: 0.8114
# Epoch 2/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0133 - classifier_out_loss: 2.9198 - decoder_out_loss: 0.0133 - classifier_out_accuracy: 0.1650 - decoder_out_accuracy: 0.8123 - val_loss: 0.0123 - val_classifier_out_loss: 2.8023 - val_decoder_out_loss: 0.0123 - val_classifier_out_accuracy: 0.1738 - val_decoder_out_accuracy: 0.8117
# Epoch 3/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0121 - classifier_out_loss: 2.7352 - decoder_out_loss: 0.0121 - classifier_out_accuracy: 0.1704 - decoder_out_accuracy: 0.8128 - val_loss: 0.0115 - val_classifier_out_loss: 2.6952 - val_decoder_out_loss: 0.0115 - val_classifier_out_accuracy: 0.1777 - val_decoder_out_accuracy: 0.8120
# Epoch 4/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0114 - classifier_out_loss: 2.6486 - decoder_out_loss: 0.0114 - classifier_out_accuracy: 0.1736 - decoder_out_accuracy: 0.8131 - val_loss: 0.0111 - val_classifier_out_loss: 2.6134 - val_decoder_out_loss: 0.0111 - val_classifier_out_accuracy: 0.1777 - val_decoder_out_accuracy: 0.8123
# Epoch 5/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0109 - classifier_out_loss: 2.5962 - decoder_out_loss: 0.0109 - classifier_out_accuracy: 0.1757 - decoder_out_accuracy: 0.8132 - val_loss: 0.0108 - val_classifier_out_loss: 2.5787 - val_decoder_out_loss: 0.0108 - val_classifier_out_accuracy: 0.1807 - val_decoder_out_accuracy: 0.8119
# Epoch 6/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0105 - classifier_out_loss: 2.5647 - decoder_out_loss: 0.0105 - classifier_out_accuracy: 0.1764 - decoder_out_accuracy: 0.8133 - val_loss: 0.0105 - val_classifier_out_loss: 2.5374 - val_decoder_out_loss: 0.0105 - val_classifier_out_accuracy: 0.1818 - val_decoder_out_accuracy: 0.8125
# Epoch 7/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0103 - classifier_out_loss: 2.5391 - decoder_out_loss: 0.0103 - classifier_out_accuracy: 0.1778 - decoder_out_accuracy: 0.8134 - val_loss: 0.0102 - val_classifier_out_loss: 2.5205 - val_decoder_out_loss: 0.0102 - val_classifier_out_accuracy: 0.1824 - val_decoder_out_accuracy: 0.8124
# Epoch 8/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0101 - classifier_out_loss: 2.5162 - decoder_out_loss: 0.0101 - classifier_out_accuracy: 0.1787 - decoder_out_accuracy: 0.8135 - val_loss: 0.0101 - val_classifier_out_loss: 2.5048 - val_decoder_out_loss: 0.0101 - val_classifier_out_accuracy: 0.1794 - val_decoder_out_accuracy: 0.8125
# Epoch 9/25
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0099 - classifier_out_loss: 2.4996 - decoder_out_loss: 0.0099 - classifier_out_accuracy: 0.1784 - decoder_out_accuracy: 0.8136 - val_loss: 0.0099 - val_classifier_out_loss: 2.4920 - val_decoder_out_loss: 0.0099 - val_classifier_out_accuracy: 0.1820 - val_decoder_out_accuracy: 0.8125
# Epoch 10/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0098 - classifier_out_loss: 2.4833 - decoder_out_loss: 0.0098 - classifier_out_accuracy: 0.1786 - decoder_out_accuracy: 0.8136 - val_loss: 0.0098 - val_classifier_out_loss: 2.4751 - val_decoder_out_loss: 0.0098 - val_classifier_out_accuracy: 0.1774 - val_decoder_out_accuracy: 0.8127
# Epoch 11/25
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0096 - classifier_out_loss: 2.4696 - decoder_out_loss: 0.0096 - classifier_out_accuracy: 0.1782 - decoder_out_accuracy: 0.8136 - val_loss: 0.0098 - val_classifier_out_loss: 2.4596 - val_decoder_out_loss: 0.0098 - val_classifier_out_accuracy: 0.1779 - val_decoder_out_accuracy: 0.8124
# Epoch 12/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0095 - classifier_out_loss: 2.4567 - decoder_out_loss: 0.0095 - classifier_out_accuracy: 0.1784 - decoder_out_accuracy: 0.8137 - val_loss: 0.0097 - val_classifier_out_loss: 2.4409 - val_decoder_out_loss: 0.0097 - val_classifier_out_accuracy: 0.1798 - val_decoder_out_accuracy: 0.8125
# Epoch 13/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0094 - classifier_out_loss: 2.4465 - decoder_out_loss: 0.0094 - classifier_out_accuracy: 0.1780 - decoder_out_accuracy: 0.8137 - val_loss: 0.0096 - val_classifier_out_loss: 2.4360 - val_decoder_out_loss: 0.0096 - val_classifier_out_accuracy: 0.1784 - val_decoder_out_accuracy: 0.8124
# Epoch 14/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0094 - classifier_out_loss: 2.4338 - decoder_out_loss: 0.0094 - classifier_out_accuracy: 0.1782 - decoder_out_accuracy: 0.8137 - val_loss: 0.0095 - val_classifier_out_loss: 2.4328 - val_decoder_out_loss: 0.0095 - val_classifier_out_accuracy: 0.1747 - val_decoder_out_accuracy: 0.8126
# Epoch 15/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0093 - classifier_out_loss: 2.4266 - decoder_out_loss: 0.0093 - classifier_out_accuracy: 0.1782 - decoder_out_accuracy: 0.8138 - val_loss: 0.0095 - val_classifier_out_loss: 2.4240 - val_decoder_out_loss: 0.0095 - val_classifier_out_accuracy: 0.1770 - val_decoder_out_accuracy: 0.8125
# Epoch 16/25
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0092 - classifier_out_loss: 2.4192 - decoder_out_loss: 0.0092 - classifier_out_accuracy: 0.1777 - decoder_out_accuracy: 0.8138 - val_loss: 0.0094 - val_classifier_out_loss: 2.4149 - val_decoder_out_loss: 0.0094 - val_classifier_out_accuracy: 0.1785 - val_decoder_out_accuracy: 0.8126
# Epoch 17/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0091 - classifier_out_loss: 2.4119 - decoder_out_loss: 0.0091 - classifier_out_accuracy: 0.1786 - decoder_out_accuracy: 0.8138 - val_loss: 0.0093 - val_classifier_out_loss: 2.4102 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.1758 - val_decoder_out_accuracy: 0.8126
# Epoch 18/25
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0091 - classifier_out_loss: 2.4069 - decoder_out_loss: 0.0091 - classifier_out_accuracy: 0.1781 - decoder_out_accuracy: 0.8138 - val_loss: 0.0093 - val_classifier_out_loss: 2.3972 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.1744 - val_decoder_out_accuracy: 0.8127
# Epoch 19/25
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0090 - classifier_out_loss: 2.4017 - decoder_out_loss: 0.0090 - classifier_out_accuracy: 0.1783 - decoder_out_accuracy: 0.8138 - val_loss: 0.0093 - val_classifier_out_loss: 2.3951 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.1711 - val_decoder_out_accuracy: 0.8127
# Epoch 20/25
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0090 - classifier_out_loss: 2.3977 - decoder_out_loss: 0.0090 - classifier_out_accuracy: 0.1776 - decoder_out_accuracy: 0.8139 - val_loss: 0.0093 - val_classifier_out_loss: 2.3923 - val_decoder_out_loss: 0.0093 - val_classifier_out_accuracy: 0.1770 - val_decoder_out_accuracy: 0.8126
# Epoch 21/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0089 - classifier_out_loss: 2.3932 - decoder_out_loss: 0.0089 - classifier_out_accuracy: 0.1777 - decoder_out_accuracy: 0.8139 - val_loss: 0.0092 - val_classifier_out_loss: 2.3874 - val_decoder_out_loss: 0.0092 - val_classifier_out_accuracy: 0.1748 - val_decoder_out_accuracy: 0.8127
# Epoch 22/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0089 - classifier_out_loss: 2.3892 - decoder_out_loss: 0.0089 - classifier_out_accuracy: 0.1778 - decoder_out_accuracy: 0.8139 - val_loss: 0.0092 - val_classifier_out_loss: 2.3902 - val_decoder_out_loss: 0.0092 - val_classifier_out_accuracy: 0.1730 - val_decoder_out_accuracy: 0.8127
# Epoch 23/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0089 - classifier_out_loss: 2.3868 - decoder_out_loss: 0.0089 - classifier_out_accuracy: 0.1779 - decoder_out_accuracy: 0.8139 - val_loss: 0.0091 - val_classifier_out_loss: 2.3765 - val_decoder_out_loss: 0.0091 - val_classifier_out_accuracy: 0.1736 - val_decoder_out_accuracy: 0.8127
# Epoch 24/25
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0088 - classifier_out_loss: 2.3847 - decoder_out_loss: 0.0088 - classifier_out_accuracy: 0.1769 - decoder_out_accuracy: 0.8139 - val_loss: 0.0091 - val_classifier_out_loss: 2.3767 - val_decoder_out_loss: 0.0091 - val_classifier_out_accuracy: 0.1715 - val_decoder_out_accuracy: 0.8128
# Epoch 25/25
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0088 - classifier_out_loss: 2.3803 - decoder_out_loss: 0.0088 - classifier_out_accuracy: 0.1779 - decoder_out_accuracy: 0.8139 - val_loss: 0.0090 - val_classifier_out_loss: 2.3746 - val_decoder_out_loss: 0.0090 - val_classifier_out_accuracy: 0.1734 - val_decoder_out_accuracy: 0.8127
# <ipython-input-6-440db8ff8ebb>:33: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
